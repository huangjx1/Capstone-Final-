# %%
# Problem statement: To Predict the Prices of private residential properties; inside CCR, OCR and RCR region as well as 
#their price difference over the last 5 years

# to note: CCR, RCR, OCR, Tenure, unit per square feet
#Group by CCR,RCR, OCR
#Group by Tenure
#i might need a timeseries of singapore inflation

# %%
import pandas as pd
import numpy as np
import pylab
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns
import re
import optuna
from optuna.samplers import TPESampler
from xgboost import XGBRegressor

from sklearn.preprocessing import OrdinalEncoder, StandardScaler
from sklearn import metrics,linear_model
from sklearn.metrics import accuracy_score, mean_squared_error
from sklearn.ensemble import RandomForestRegressor

from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.linear_model import LinearRegression,Lasso

# %% [markdown]
# ## Removing the first row which merged all columns together in the csv file

# %%
house1 = pd.read_csv('./dataset_asof_051121/house1.csv',skiprows = [0])
house2 = pd.read_csv('./dataset_asof_051121/house2.csv',skiprows = [0])
house3 = pd.read_csv('./dataset_asof_051121/house3.csv',skiprows = [0])
house4 = pd.read_csv('./dataset_asof_051121/house4.csv',skiprows = [0])
house5 = pd.read_csv('./dataset_asof_051121/house5.csv',skiprows = [0])
house6 = pd.read_csv('./dataset_asof_051121/house6.csv',skiprows = [0])

# %% [markdown]
# ## Looking at the house data shape

# %%
print(house1.shape)
print(house2.shape)
print(house3.shape)
print(house4.shape)
print(house5.shape)
print(house6.shape)
# Out:
# (305, 16)
# (883, 16)
# (2578, 16)
# (3370, 16)
# (1595, 16)
# (1084, 16)

# %%
house1.dtypes
# Out:
# S/N                   object
# Project Name          object
# Street Name           object
# Type                  object
# Postal District      float64
# Market Segment        object
# Tenure                object
# Type of Sale          object
# No. of Units         float64
# Price ($)            float64
# Nett Price ($)        object
# Area (Sqft)          float64
# Type of Area          object
# Floor Level           object
# Unit Price ($psf)    float64
# Date of Sale          object
# dtype: object

# %% [markdown]
# ### It was noticed that alot of the base of each csv has text with NaN

# %%
house1.dropna(axis = 0, inplace = True)
house2.dropna(axis = 0, inplace = True)
house3.dropna(axis = 0, inplace = True)
house4.dropna(axis = 0, inplace = True)
house5.dropna(axis = 0, inplace = True)
house6.dropna(axis = 0, inplace = True)

# %%
house1.shape
# Out:
# (291, 16)

# %%
house1.head()
# Out:
#   S/N                Project Name          Street Name           Type  \
# 0   1  LANDED HOUSING DEVELOPMENT  PASIR PANJANG DRIVE        Terrace
# 1   2                     OCEAN 8          OCEAN DRIVE        Terrace
# 2   3  LANDED HOUSING DEVELOPMENT          OCEAN DRIVE       Detached
# 3   4          WEST COAST GARDENS      WEST COAST PARK  Semi-detached
# 4   5  LANDED HOUSING DEVELOPMENT     JALAN MAS KUNING        Terrace
#
#    Postal District Market Segment                              Tenure  \
# 0              5.0            RCR                            Freehold
# 1              4.0            CCR   99 yrs lease commencing from 2005
# 2              4.0            CCR   99 yrs lease commencing from 2005
# 3              5.0            OCR  956 yrs lease commencing from 1928
# 4              5.0            OCR                            Freehold
#
#   Type of Sale  No. of Units   Price ($) Nett Price ($)  Area (Sqft)  \
# ...

# %%
house1.tail()
# Out:
#      S/N                Project Name         Street Name     Type  \
# 286  287             CHELSEA VILLAGE        JAMBOL PLACE  Terrace
# 287  288  LANDED HOUSING DEVELOPMENT     WEST COAST ROAD  Terrace
# 288  289            WESTPEAK TERRACE     WEST COAST WALK  Terrace
# 289  290                  VILLAS SIX  PASIR PANJANG ROAD  Terrace
# 290  291            CHWEE CHIAN VIEW    CHWEE CHIAN VIEW  Terrace
#
#      Postal District Market Segment    Tenure Type of Sale  No. of Units  \
# 286              5.0            RCR  Freehold       Resale           1.0
# 287              5.0            OCR  Freehold       Resale           1.0
# 288              5.0            OCR  Freehold       Resale           1.0
# 289              5.0            RCR  Freehold       Resale           1.0
# 290              5.0            RCR  Freehold       Resale           1.0
#
#      Price ($) Nett Price ($)  Area (Sqft) Type of Area Floor Level  \
# ...

# %% [markdown]
# ### Data exploration and cleaning

# %%
house1.isnull().sum()
# Out:
# S/N                  0
# Project Name         0
# Street Name          0
# Type                 0
# Postal District      0
# Market Segment       0
# Tenure               0
# Type of Sale         0
# No. of Units         0
# Price ($)            0
# Nett Price ($)       0
# Area (Sqft)          0
# Type of Area         0
# Floor Level          0
# Unit Price ($psf)    0
# Date of Sale         0
# dtype: int64

# %%
house1.dtypes
# Out:
# S/N                   object
# Project Name          object
# Street Name           object
# Type                  object
# Postal District      float64
# Market Segment        object
# Tenure                object
# Type of Sale          object
# No. of Units         float64
# Price ($)            float64
# Nett Price ($)        object
# Area (Sqft)          float64
# Type of Area          object
# Floor Level           object
# Unit Price ($psf)    float64
# Date of Sale          object
# dtype: object

# %%
merged_house = pd.concat([house1, house2, house3, house4, house5, house6])

# %%
merged_house.reset_index(drop = True, inplace = True)

# %%
merged_house.drop(['S/N'], axis=1, inplace = True)

# %%
merged_house.shape
# Out:
# (9728, 15)

# %%
merged_house.tail()
# Out:
#                     Project Name      Street Name           Type  \
# 9723              MIMOSA TERRACE      MIMOSA VIEW        Terrace
# 9724               SARACA VILLAS   SARACA TERRACE        Terrace
# 9725              GERALD GARDENS  GERALD CRESCENT        Terrace
# 9726  LANDED HOUSING DEVELOPMENT     JALAN SANKAM  Semi-detached
# 9727  LANDED HOUSING DEVELOPMENT         NIM ROAD       Detached
#
#       Postal District Market Segment                              Tenure  \
# 9723             28.0            OCR                            Freehold
# 9724             28.0            OCR   99 yrs lease commencing from 1997
# 9725             28.0            OCR  999 yrs lease commencing from 1879
# 9726             27.0            OCR                            Freehold
# 9727             28.0            OCR                            Freehold
#
#      Type of Sale  No. of Units   Price ($) Nett Price ($)  Area (Sqft)  \
# ...

# %%
merged_house.reset_index(drop = False , inplace = True)

# %%
merged_house.tail()
# Out:
#       index                Project Name      Street Name           Type  \
# 9723   9723              MIMOSA TERRACE      MIMOSA VIEW        Terrace
# 9724   9724               SARACA VILLAS   SARACA TERRACE        Terrace
# 9725   9725              GERALD GARDENS  GERALD CRESCENT        Terrace
# 9726   9726  LANDED HOUSING DEVELOPMENT     JALAN SANKAM  Semi-detached
# 9727   9727  LANDED HOUSING DEVELOPMENT         NIM ROAD       Detached
#
#       Postal District Market Segment                              Tenure  \
# 9723             28.0            OCR                            Freehold
# 9724             28.0            OCR   99 yrs lease commencing from 1997
# 9725             28.0            OCR  999 yrs lease commencing from 1879
# 9726             27.0            OCR                            Freehold
# 9727             28.0            OCR                            Freehold
#
#      Type of Sale  No. of Units   Price ($) Nett Price ($)  Area (Sqft)  \
# ...

# %% [markdown]
# ## Export to csv file to notebook files

# %%
merged_house.to_csv('./dataset_asof_051121/merged_house.csv', index=False)

# %%
merged_house.head()
# Out:
#    index                Project Name          Street Name           Type  \
# 0      0  LANDED HOUSING DEVELOPMENT  PASIR PANJANG DRIVE        Terrace
# 1      1                     OCEAN 8          OCEAN DRIVE        Terrace
# 2      2  LANDED HOUSING DEVELOPMENT          OCEAN DRIVE       Detached
# 3      3          WEST COAST GARDENS      WEST COAST PARK  Semi-detached
# 4      4  LANDED HOUSING DEVELOPMENT     JALAN MAS KUNING        Terrace
#
#    Postal District Market Segment                              Tenure  \
# 0              5.0            RCR                            Freehold
# 1              4.0            CCR   99 yrs lease commencing from 2005
# 2              4.0            CCR   99 yrs lease commencing from 2005
# 3              5.0            OCR  956 yrs lease commencing from 1928
# 4              5.0            OCR                            Freehold
#
#   Type of Sale  No. of Units   Price ($) Nett Price ($)  Area (Sqft)  \
# ...

# %%
merged_house.dtypes
# Out:
# index                  int64
# Project Name          object
# Street Name           object
# Type                  object
# Postal District      float64
# Market Segment        object
# Tenure                object
# Type of Sale          object
# No. of Units         float64
# Price ($)            float64
# Nett Price ($)        object
# Area (Sqft)          float64
# Type of Area          object
# Floor Level           object
# Unit Price ($psf)    float64
# Date of Sale          object
# dtype: object

# %% [markdown]
# ## Renaming columns in the dataframe for easy typing

# %%
merged_house.rename(columns = {"Price ($)":"Price", "Nett Price ($)": "Nett Price", "Area (Sqft)": "Areasq", 
                               "Unit Price ($psf)": "Unit Price psf"}, inplace = True)

# %%
merged_house.head(1)
# Out:
#    index                Project Name          Street Name     Type  \
# 0      0  LANDED HOUSING DEVELOPMENT  PASIR PANJANG DRIVE  Terrace
#
#    Postal District Market Segment    Tenure Type of Sale  No. of Units  \
# 0              5.0            RCR  Freehold       Resale           1.0
#
#        Price Nett Price  Areasq Type of Area Floor Level  Unit Price psf  \
# 0  3660000.0          -  2566.0         Land           -          1426.0
#
#   Date of Sale
# 0     Oct-2021

# %%
merged_house.columns = merged_house.columns.str.lower()

# %%
merged_house.head(1)
# Out:
#    index                project name          street name     type  \
# 0      0  LANDED HOUSING DEVELOPMENT  PASIR PANJANG DRIVE  Terrace
#
#    postal district market segment    tenure type of sale  no. of units  \
# 0              5.0            RCR  Freehold       Resale           1.0
#
#        price nett price  areasq type of area floor level  unit price psf  \
# 0  3660000.0          -  2566.0         Land           -          1426.0
#
#   date of sale
# 0     Oct-2021

# %%
merged_house['project name'].value_counts()
# Out:
# LANDED HOUSING DEVELOPMENT    3923
# SERANGOON GARDEN ESTATE        465
# SELETAR HILLS ESTATE           242
# OPERA ESTATE                   210
# SEMBAWANG HILLS ESTATE         194
#                               ...
# CHUAN VALE                       1
# THE SILVA GARDENS                1
# ONE SURIN                        1
# PROSPECT GARDEN                  1
# SEMBAWANG SQUARE ESTATE          1
# Name: project name, Length: 471, dtype: int64

# %%
merged_house['market segment'].value_counts()
# Out:
# OCR    6555
# RCR    1789
# CCR    1384
# Name: market segment, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(y = merged_house['unit price psf'], x = merged_house['market segment'] )
# Out:
# <AxesSubplot:xlabel='market segment', ylabel='unit price psf'>

# %%
plt.figure(figsize =(8,5))
ax = sns.boxplot('market segment', 'unit price psf', data = merged_house);
# Out:
# C:\Users\jiexi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
merged_house['unit price psf'].value_counts()
# Out:
# 1000.0    25
# 1348.0    20
# 1250.0    19
# 1109.0    19
# 1100.0    18
#           ..
# 2538.0     1
# 2661.0     1
# 2521.0     1
# 2883.0     1
# 695.0      1
# Name: unit price psf, Length: 1954, dtype: int64

# %%
merged_house['price'].value_counts()
# Out:
# 3000000.0     159
# 2800000.0     143
# 3500000.0     108
# 2600000.0     105
# 2500000.0     103
#              ...
# 6168000.0       1
# 36882500.0      1
# 8738000.0       1
# 2398888.0       1
# 3398888.0       1
# Name: price, Length: 1892, dtype: int64

# %%
sns.set(font_scale=3)
plt.figure(figsize =(50,10))
district_place = sns.boxplot('postal district', 'unit price psf', data = merged_house, color ='blue');
# Out:
# C:\Users\jiexi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.set(font_scale=3)
plt.figure(figsize =(50,10))
type_of_hold = sns.boxplot('tenure', 'unit price psf', data = merged_house, color ='blue');
# Out:
# C:\Users\jiexi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
pd.set_option('max_columns',None)
pd.set_option('max_rows',None)

# %%
merged_house.shape
# Out:
# (9728, 16)

# %%
merged_house['tenure'].value_counts().head()
# Out:
# Freehold                              6480
# 999 yrs lease commencing from 1879     491
# 99 yrs lease commencing from 1994      309
# 99 yrs lease commencing from 1996      183
# 99 yrs lease commencing from 1997      178
# Name: tenure, dtype: int64

# %% [markdown]
# ### 65 types of different tenure

# %%
merged_house['tenure'].nunique()
# Out:
# 65

# %%
tenure_list = merged_house['tenure']

# %%
tenure_list = merged_house['tenure']
tenure_split = tenure_list.str.split()[0]

# %% [markdown]
# Taking out the 1st word from tenure and replace freehold with 999
# Taking out the last word from tenure, since freehold is also the last word for freehold, change it to 999

# %%
first = merged_house['tenure'].str.split().str[0]
last = merged_house['tenure'].str.split().str[-1]

# %%
first.replace({'Freehold':999}, inplace = True)
last.replace({'Freehold':999}, inplace = True)

# %%
first = first.astype(int)

# %%
last = last.astype(int)

# %%
tenure = first + last - 2021

# %%
tenure.replace({-23:999}, inplace = True)

# %%
tenure.head()
# Out:
# 0    999
# 1     83
# 2     83
# 3    863
# 4    999
# Name: tenure, dtype: int64

# %%
tenure_list.head(10)
# Out:
# 0                              Freehold
# 1     99 yrs lease commencing from 2005
# 2     99 yrs lease commencing from 2005
# 3    956 yrs lease commencing from 1928
# 4                              Freehold
# 5                              Freehold
# 6     99 yrs lease commencing from 2005
# 7                              Freehold
# 8     99 yrs lease commencing from 2007
# 9    956 yrs lease commencing from 1928
# Name: tenure, dtype: object

# %%
merged_house.drop(columns = 'tenure', inplace = True)

# %%
merged_house.shape
# Out:
# (9728, 15)

# %%
merged_house.insert(0, "tenure",tenure)

# %%
merged_house.head()
# Out:
#    tenure  index                project name          street name  \
# 0     999      0  LANDED HOUSING DEVELOPMENT  PASIR PANJANG DRIVE
# 1      83      1                     OCEAN 8          OCEAN DRIVE
# 2      83      2  LANDED HOUSING DEVELOPMENT          OCEAN DRIVE
# 3     863      3          WEST COAST GARDENS      WEST COAST PARK
# 4     999      4  LANDED HOUSING DEVELOPMENT     JALAN MAS KUNING
#
#             type  postal district market segment type of sale  no. of units  \
# 0        Terrace              5.0            RCR       Resale           1.0
# 1        Terrace              4.0            CCR       Resale           1.0
# 2       Detached              4.0            CCR       Resale           1.0
# 3  Semi-detached              5.0            OCR       Resale           1.0
# 4        Terrace              5.0            OCR       Resale           1.0
#
#         price nett price  areasq type of area floor level  unit price psf  \
# ...

# %%
merged_house = merged_house[['index','project name', 'street name', 'type', 'tenure', 'postal district', 'market segment',
                            'type of sale', 'no. of units', 'price', 'nett price', 'areasq', 'type of area', 'floor level',
                            'unit price psf', 'date of sale']]

# %%
merged_house.head(1)
# Out:
#    index                project name          street name     type  tenure  \
# 0      0  LANDED HOUSING DEVELOPMENT  PASIR PANJANG DRIVE  Terrace     999
#
#    postal district market segment type of sale  no. of units      price  \
# 0              5.0            RCR       Resale           1.0  3660000.0
#
#   nett price  areasq type of area floor level  unit price psf date of sale
# 0          -  2566.0         Land           -          1426.0     Oct-2021

# %% [markdown]
# ## Taking a look at the tenure and unit price psf (per sq feet)

# %%
sns.set(font_scale=1)
plt.figure(figsize=(5,3))
sns.scatterplot(y = merged_house['unit price psf'], x = merged_house['tenure'])
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='unit price psf'>

# %%
merged_house['tenure'].max()
# Out:
# 9944

# %%
merged_house['tenure'].idxmax()
# Out:
# 2801

# %%
merged_house.loc[2801]
# Out:
# index                                    2801
# project name       LANDED HOUSING DEVELOPMENT
# street name                  WOODSVILLE CLOSE
# type                                  Terrace
# tenure                                   9944
# postal district                          13.0
# market segment                            RCR
# type of sale                           Resale
# no. of units                              2.0
# price                               8400000.0
# nett price                                  -
# areasq                                 3601.0
# type of area                             Land
# floor level                                 -
# unit price psf                         2333.0
# date of sale                         Jul-2018
# Name: 2801, dtype: object

# %%
merged_house['tenure'].replace({9944: 999}, inplace = True)

# %%
merged_house.loc[2801]
# Out:
# index                                    2801
# project name       LANDED HOUSING DEVELOPMENT
# street name                  WOODSVILLE CLOSE
# type                                  Terrace
# tenure                                    999
# postal district                          13.0
# market segment                            RCR
# type of sale                           Resale
# no. of units                              2.0
# price                               8400000.0
# nett price                                  -
# areasq                                 3601.0
# type of area                             Land
# floor level                                 -
# unit price psf                         2333.0
# date of sale                         Jul-2018
# Name: 2801, dtype: object

# %% [markdown]
# ### We can see a positive corelation. However, there seems to be a stagnant from 99 years to the range of 750 to 900 years. The only exception for the high prices occurence will be from the free hold which we have listed it as 999 years in the dataframe

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(y = merged_house['unit price psf'], x = merged_house['tenure'])
plt.axvline(x=99, color = 'red')

# %%
merged_house['type'].value_counts()
# Out:
# Terrace          5556
# Semi-detached    2889
# Detached         1283
# Name: type, dtype: int64

# %%
plt.figure(figsize =(5,5))
type_of_house = sns.boxplot('type', 'unit price psf', data = merged_house);
# Out:
# C:\Users\jiexi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize =(5,5))
type_of_house = sns.boxplot('type of sale', 'unit price psf', data = merged_house);
# Out:
# C:\Users\jiexi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Not much difference between the 3 types except for the outlier

# %% [markdown]
# ### Identifying outliers in the boxplot

# %%
merged_house.dtypes
# Out:
# index                int64
# project name        object
# street name         object
# type                object
# tenure               int64
# postal district    float64
# market segment      object
# type of sale        object
# no. of units       float64
# price              float64
# nett price          object
# areasq             float64
# type of area        object
# floor level         object
# unit price psf     float64
# date of sale        object
# dtype: object

# %%
merged_house.nlargest(10,'unit price psf', keep ='all')
# Out:
#      index                    project name        street name      type  \
# 528    528      LANDED HOUSING DEVELOPMENT  EMERALD HILL ROAD   Terrace
# 853    853      LANDED HOUSING DEVELOPMENT     CAIRNHILL ROAD  Detached
# 461    461      LANDED HOUSING DEVELOPMENT      SAUNDERS ROAD   Terrace
# 497    497  EMERALD HILL CONSERVATION AREA  EMERALD HILL ROAD   Terrace
# 639    639      LANDED HOUSING DEVELOPMENT  EMERALD HILL ROAD   Terrace
# 330    330  EMERALD HILL CONSERVATION AREA  EMERALD HILL ROAD   Terrace
# 498    498  EMERALD HILL CONSERVATION AREA  EMERALD HILL ROAD   Terrace
# 621    621     CAIRNHILL CONSERVATION AREA     CAIRNHILL ROAD   Terrace
# 345    345      LANDED HOUSING DEVELOPMENT    DEVONSHIRE ROAD   Terrace
# 719    719  EMERALD HILL CONSERVATION AREA  EMERALD HILL ROAD   Terrace
#
#      tenure  postal district market segment type of sale  no. of units  \
# 528     999              9.0            CCR       Resale           1.0
# ...

# %% [markdown]
# ### Removing top 2 outliers, exceeding $5000 psf

# %%
merged_house = merged_house[merged_house['unit price psf'] <= 5000]

# %%
merged_house.shape
# Out:
# (9726, 16)

# %%
merged_house.head(1)
# Out:
#    index                project name          street name     type  tenure  \
# 0      0  LANDED HOUSING DEVELOPMENT  PASIR PANJANG DRIVE  Terrace     999
#
#    postal district market segment type of sale  no. of units      price  \
# 0              5.0            RCR       Resale           1.0  3660000.0
#
#   nett price  areasq type of area floor level  unit price psf date of sale
# 0          -  2566.0         Land           -          1426.0     Oct-2021

# %%
print(merged_house.iloc[528])
print(merged_house.iloc[853])
print(merged_house.iloc[461])

#Emerald Hill Road is a heritage preserved area (freehold), due to this, the price  is extremely high
#for Cairnhills and Sauder Roads, both are freehold
# Out:
# index                         529
# project name         MCMAHON PARK
# street name        JALAN ISTIMEWA
# type                Semi-detached
# tenure                        855
# postal district              10.0
# market segment                CCR
# type of sale               Resale
# no. of units                  1.0
# price                   6400000.0
# nett price                      -
# areasq                     3739.0
# type of area                 Land
# floor level                     -
# unit price psf             1711.0
# date of sale             Jan-2021
# Name: 529, dtype: object
# index                                     855
# project name       LANDED HOUSING DEVELOPMENT
# street name                   SWETTENHAM ROAD
# type                                 Detached
# tenure                                    999
# postal district                          10.0
# market segment                            CCR
# type of sale                           Resale
# ...

# %%
merged_house1 = merged_house.copy(deep = True)

# %%
merged_house1.shape
# Out:
# (9726, 16)

# %%
#merged_house1.drop(labels =[461, 528, 853], axis = 0, inplace = True)

# %%
merged_house1['project name'].nunique()
# Out:
# 471

# %%
merged_house1['postal district'].nunique()
# Out:
# 24

# %%
merged_house1['market segment'].nunique()
# Out:
# 3

# %% [markdown]
# ## We can dummify district and market segment for better features arrangment

# %%
merged_house1 = pd.get_dummies(merged_house1, columns =['market segment', 'postal district', 'type'])

# %%
merged_house1.head(1)
# Out:
#    index                project name          street name  tenure  \
# 0      0  LANDED HOUSING DEVELOPMENT  PASIR PANJANG DRIVE     999
#
#   type of sale  no. of units      price nett price  areasq type of area  \
# 0       Resale           1.0  3660000.0          -  2566.0         Land
#
#   floor level  unit price psf date of sale  market segment_CCR  \
# 0           -          1426.0     Oct-2021                   0
#
#    market segment_OCR  market segment_RCR  postal district_2.0  \
# 0                   0                   1                    0
#
#    postal district_3.0  postal district_4.0  postal district_5.0  \
# 0                    0                    0                    1
#
#    postal district_8.0  postal district_9.0  postal district_10.0  \
# 0                    0                    0                     0
#
#    postal district_11.0  postal district_12.0  postal district_13.0  \
# 0                     0                     0                     0
#
# ...

# %%
merged_house1.shape
# Out:
# (9726, 43)

# %% [markdown]
# Price and unit psf have slight corelation, to gauge a house price property, psf will be a better comparison

# %%
sns.set(font_scale=1)
plt.figure(figsize =(5,10))
sns.heatmap(merged_house1.corr()[['unit price psf']].sort_values('unit price psf', ascending =False), annot=True, vmin = -1, vmax = 1, cmap = 'coolwarm');

# %% [markdown]
# ### Train test split and linear regression

# %%
merged_house1.head(1)
# Out:
#    index                project name          street name  tenure  \
# 0      0  LANDED HOUSING DEVELOPMENT  PASIR PANJANG DRIVE     999
#
#   type of sale  no. of units      price nett price  areasq type of area  \
# 0       Resale           1.0  3660000.0          -  2566.0         Land
#
#   floor level  unit price psf date of sale  market segment_CCR  \
# 0           -          1426.0     Oct-2021                   0
#
#    market segment_OCR  market segment_RCR  postal district_2.0  \
# 0                   0                   1                    0
#
#    postal district_3.0  postal district_4.0  postal district_5.0  \
# 0                    0                    0                    1
#
#    postal district_8.0  postal district_9.0  postal district_10.0  \
# 0                    0                    0                     0
#
#    postal district_11.0  postal district_12.0  postal district_13.0  \
# 0                     0                     0                     0
#
# ...

# %%
X = merged_house1.drop(columns = ['unit price psf','price','project name','street name','type of sale','nett price', 'type of area', 'floor level','date of sale', 'index'])
y = merged_house1['unit price psf']

# %%
# Create train/test splits.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size =0.25, random_state=42)

# %%
merged_house1.dtypes
# Out:
# index                     int64
# project name             object
# street name              object
# tenure                    int64
# type of sale             object
# no. of units            float64
# price                   float64
# nett price               object
# areasq                  float64
# type of area             object
# floor level              object
# unit price psf          float64
# date of sale             object
# market segment_CCR        uint8
# market segment_OCR        uint8
# market segment_RCR        uint8
# postal district_2.0       uint8
# postal district_3.0       uint8
# postal district_4.0       uint8
# postal district_5.0       uint8
# postal district_8.0       uint8
# postal district_9.0       uint8
# postal district_10.0      uint8
# postal district_11.0      uint8
# postal district_12.0      uint8
# postal district_13.0      uint8
# postal district_14.0      uint8
# postal district_15.0      uint8
# postal district_16.0      uint8
# ...

# %%
sc = StandardScaler()
Z_train = sc.fit_transform(X_train)
Z_test = sc.transform(X_test)

# %%
# instantiate the model
lr = LinearRegression()
#fit using the training data
lr.fit(Z_train, y_train);

# %%
lr.score(Z_train, y_train)
# Out:
# 0.474309247461115

# %%
lr.score(Z_test, y_test)
#RMSE
# Out:
# 0.46366565638449475

# %%
y_pred = lr.predict(Z_train)

# %%
metrics.r2_score(y_train, y_pred)
# Out:
# 0.474309247461115

# %%
metrics.mean_squared_error(y_train, y_pred)
# Out:
# 108971.37969306824

# %%
np.sqrt(metrics.mean_squared_error(y_train, y_pred))
# Out:
# 330.1081333337127

# %% [markdown]
# LINE assumptions

# %%
plt.scatter(y_train, y_pred, s = 5)
# We can see this is quite linear except for a few outliers

# %%
#how to do for independence?

# %%
plt.scatter(y_pred, y_train - y_pred, s=5)
plt.axhline(0, color ='orange');
# Graph is homoscadecity

# %%
#plt.scatter()
#Do a qq plot

# %% [markdown]
# # IS LASSO important if there is no overfitting?

# %%
# State the parameters you want to search for lasso regularisation
# we want to go through 1000 different alpha values
parameters = {
                'alpha': [x/1 for x in range(1000)]
             }

# Instantiate the model
lasso = Lasso()

# Instantiate Gridsearch (use previous instantiated parameters and model)
lasso_lr = GridSearchCV(lasso, parameters, 
                     scoring='neg_mean_squared_error', 
                     cv=5, verbose=1, n_jobs=-1)

# %%
lasso_lr.fit(Z_train, y_train);
# Out:
# Fitting 5 folds for each of 1000 candidates, totalling 5000 fits

# %%
print(lasso_lr.best_params_)
# Out:
# {'alpha': 4.0}

# %%
lasso_reg = linear_model.Lasso(alpha = 1, max_iter=10000000, tol=0.1)

# %%
lasso_reg.fit(Z_train, y_train)
# Out:
# Lasso(alpha=1, max_iter=10000000, tol=0.1)

# %%
lasso_reg.score(Z_train, y_train)
# Out:
# 0.4741596644634807

# %%
lasso_reg.score(Z_test, y_test)
# Out:
# 0.46199959601462437

# %% [markdown]
# # LINE Assumption

# %%
#plt.scatter(merged_house1["areasq"], merged_house1["unit price psf"], s=1)
#plt.xlabel('areasq')
#plt.ylabel('unit price psf');

# %%
plt.scatter(merged_house1["areasq"], merged_house1["price"], s=1)
plt.xlabel('areqsq')
plt.ylabel('price');

# %%
#plt.hist(put MSE, bins=50);

# %% [markdown]
# ### XGboost

# %%
XGB = XGBRegressor()
XGB.fit(Z_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
XGB.score(Z_train, y_train)
# Out:
# 0.812875181495037

# %%
XGB.score(Z_test, y_test)
# Out:
# 0.6462207751367683

# %%
XGB_params ={
    'max_depth':[3, 4, 5],
    'sub_sample': [0.5],
    'colsample_bytree':[0.5],
    'min_child_weight': [5, 10, 15],
    'reg_lambda':[0.75, 2],
    'reg_alpha':[0.75, 2],
    'n_estimator':[10, 50, 100],
    'learning_rate':[0.1]
}
gs = GridSearchCV(XGB, param_grid =XGB_params, cv = 5, n_jobs =-1)
gs.fit(Z_train, y_train)
gs.best_params_
# Out:
# [18:49:10] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# {'colsample_bytree': 0.5,
#  'learning_rate': 0.1,
#  'max_depth': 5,
#  'min_child_weight': 5,
#  'n_estimator': 10,
#  'reg_alpha': 2,
#  'reg_lambda': 0.75,
#  'sub_sample': 0.5}

# %%
gs.score(Z_train, y_train)
# Out:
# 0.7037204436487081

# %%
gs.score(Z_test, y_test)
# Out:
# 0.6761147132413947

# %%
validation_scores = pd.DataFrame(gs.cv_results_)

# %%
validation_scores.head(5)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.625742      0.041016         0.005311        0.002157
# 1       0.620311      0.023378         0.005909        0.000937
# 2       0.650558      0.022783         0.015738        0.010330
# 3       0.653743      0.024947         0.006623        0.001506
# 4       0.630065      0.030959         0.005200        0.000748
#
#   param_colsample_bytree param_learning_rate param_max_depth  \
# 0                    0.5                 0.1               3
# 1                    0.5                 0.1               3
# 2                    0.5                 0.1               3
# 3                    0.5                 0.1               3
# 4                    0.5                 0.1               3
#
#   param_min_child_weight param_n_estimator param_reg_alpha param_reg_lambda  \
# 0                      5                10            0.75             0.75
# ...

# %%
XGB_params ={
    'max_depth':[5,8],
    'sub_sample': [0.25],
    'colsample_bytree':[0.39897460542748503],
    'min_child_weight': [2],
    'reg_lambda':[13.737491394307597],
    'reg_alpha':[2.428817924901067e-06],
    'n_estimator':[10],
    'learning_rate':[0.26633652161569904]
}
gs2 = GridSearchCV(XGB, param_grid =XGB_params, cv = 5, n_jobs =-1)
gs2.fit(Z_train, y_train)
gs2.best_params_
# Out:
# [18:49:12] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# {'colsample_bytree': 0.39897460542748503,
#  'learning_rate': 0.26633652161569904,
#  'max_depth': 8,
#  'min_child_weight': 2,
#  'n_estimator': 10,
#  'reg_alpha': 2.428817924901067e-06,
#  'reg_lambda': 13.737491394307597,
#  'sub_sample': 0.25}

# %%
gs2.score(Z_train, y_train)
# Out:
# 0.7533972196272591

# %%
gs2.score(Z_test, y_test)
# Out:
# 0.6772250683584639

# %%
validation_scores = pd.DataFrame(gs2.cv_results_)

# %%
validation_scores.head(5)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.915678      0.039461         0.006164        0.000705
# 1       1.088084      0.282867         0.007909        0.001205
#
#   param_colsample_bytree param_learning_rate param_max_depth  \
# 0               0.398975            0.266337               5
# 1               0.398975            0.266337               8
#
#   param_min_child_weight param_n_estimator param_reg_alpha param_reg_lambda  \
# 0                      2                10        0.000002        13.737491
# 1                      2                10        0.000002        13.737491
#
#   param_sub_sample                                             params  \
# 0             0.25  {'colsample_bytree': 0.39897460542748503, 'lea...
# 1             0.25  {'colsample_bytree': 0.39897460542748503, 'lea...
#
#    split0_test_score  split1_test_score  split2_test_score  split3_test_score  \
# ...

# %%
XGB3 = XGBRegressor(colsample_bytree= 0.5, learning_rate= 0.01, max_depth= 3, min_child_weight= 5, n_estimator= 1,
reg_alpha= 0.5, reg_lambda= 0.5, sub_sample= 0.25)
XGB3.fit(Z_train, y_train)
# Out:
# [18:49:12] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.5, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.01, max_delta_step=0,
#              max_depth=3, min_child_weight=5, missing=nan,
#              monotone_constraints='()', n_estimator=1, n_estimators=100,
#              n_jobs=8, num_parallel_tree=1, predictor='auto', random_state=0,
# ...

# %%
XGB3.score(Z_train, y_train)
# Out:
# -0.8107207721025209

# %%
XGB3.score(Z_test, y_test)
# Out:
# -0.7463749680912255

# %%
def xgb(search):
    colsample_bytree = search.suggest_float("colsample_bytree", 0.1, 1.0)
    learning_rate = search.suggest_float("learning_rate", 0.1, 1.0) 
    max_depth = search.suggest_int("max_depth",1, 5)
    min_child_weight = search.suggest_int("min_child_weight", 1, 5)
    n_estimator = search.suggest_int("n_estimators", 100, 300)
    reg_lambda = search.suggest_loguniform("reg_lambda", 1e-8, 100)
    reg_alpha = search.suggest_loguniform("reg_alpha", 1e-8, 100)
    sub_sample = search.suggest_float("sub_sample", 0.1, 1.0)
    
    model = XGBRegressor(random_state = 42,
                         colsample_bytree = colsample_bytree,
                         learning_rate = learning_rate,
                         max_depth = max_depth,
                         min_child_weight = min_child_weight,
                         n_estimator = n_estimator,
                         reg_lambda = reg_lambda, 
                         reg_alpha = reg_alpha,
                         sub_sample = sub_sample,
                         n_jobs = -1
                        )
    
    score = cross_val_score(model, Z_train, y_train, scoring = 'neg_root_mean_squared_error', cv = 5, verbose = 1)
    mean_score = score.mean()
    std_score = score.std()
    
    accuracy = mean_score - std_score
    
    return accuracy

study = optuna.create_study(direction = 'maximize', sampler = TPESampler(seed =42))
study.optimize(xgb, n_trials=100)
# Out:
# [I 2021-12-09 18:49:13,036] A new study created in memory with name: no-name-113630b6-17e5-4033-9da1-0ed3f6277e2b
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [18:49:13] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:49:13] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
# ...

# %%
study.best_params
# Out:
# {'colsample_bytree': 0.39897460542748503,
#  'learning_rate': 0.26633652161569904,
#  'max_depth': 5,
#  'min_child_weight': 2,
#  'n_estimators': 275,
#  'reg_lambda': 13.737491394307597,
#  'reg_alpha': 2.428817924901067e-06,
#  'sub_sample': 0.21762636618335934}

# %%
study.best_trial.value
# Out:
# -268.8394322175091

# %%
XGB4 = XGBRegressor(colsample_bytree= 0.39897460542748503, learning_rate= 0.26633652161569904, max_depth= 5, min_child_weight= 2, n_estimators= 275,
reg_alpha= 2.428817924901067e-06, reg_lambda= 13.737491394307597, sub_sample= 0.21762636618335934)
XGB4.fit(Z_train, y_train)
# Out:
# [18:50:59] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.39897460542748503,
#              enable_categorical=False, gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.26633652161569904,
#              max_delta_step=0, max_depth=5, min_child_weight=2, missing=nan,
#              monotone_constraints='()', n_estimators=275, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=0,
# ...

# %%
XGB4.score(Z_train, y_train)
# Out:
# 0.7440260161072909

# %%
XGB4.score(Z_test, y_test)
# Out:
# 0.6765425470871497

# %%
rf = RandomForestRegressor()

# %%
rf = RandomForestRegressor(n_estimators=200, max_depth = 5, random_state = 42)

# %%
rf.fit(Z_train, y_train);

# %%
rf.score(Z_train, y_train)
# Out:
# 0.6124523183726164

# %%
rf.score(Z_test, y_test)
# Out:
# 0.5947922268375062

# %%
rf_params ={
    'n_estimators':[300, 500, 1000],
    'max_depth':[7, 10, 20],
    'max_leaf_nodes':[50, 100]
    
    
}
rfgs = GridSearchCV(rf, param_grid = rf_params, cv = 5, n_jobs =-1)
rfgs.fit(Z_train, y_train)
rfgs.best_params_
# Out:
# {'max_depth': 20, 'max_leaf_nodes': 100, 'n_estimators': 1000}

# %%
rfgs.score(Z_train, y_train)
# Out:
# 0.7188237348052392

# %%
rfgs.score(Z_test, y_test)
# Out:
# 0.6555355964210066

# %% [markdown]
# ### Removing a total outliers not under normal distributions)

# %%
merged_house1.head()
# Out:
#    index                project name          street name  tenure  \
# 0      0  LANDED HOUSING DEVELOPMENT  PASIR PANJANG DRIVE     999
# 1      1                     OCEAN 8          OCEAN DRIVE      83
# 2      2  LANDED HOUSING DEVELOPMENT          OCEAN DRIVE      83
# 3      3          WEST COAST GARDENS      WEST COAST PARK     863
# 4      4  LANDED HOUSING DEVELOPMENT     JALAN MAS KUNING     999
#
#   type of sale  no. of units       price nett price  areasq type of area  \
# 0       Resale           1.0   3660000.0          -  2566.0         Land
# 1       Resale           1.0   6920000.0          -  3852.0         Land
# 2       Resale           1.0  17888000.0          -  8746.0         Land
# 3       Resale           1.0   5400000.0          -  4806.0         Land
# 4       Resale           1.0   2660000.0          -  1640.0         Land
#
#   floor level  unit price psf date of sale  market segment_CCR  \
# ...

# %%
merged_house1.tail(1)
# Out:
#       index                project name street name  tenure type of sale  \
# 9727   9727  LANDED HOUSING DEVELOPMENT    NIM ROAD     999       Resale
#
#       no. of units       price nett price  areasq type of area floor level  \
# 9727           1.0  10300000.0          -  9955.0         Land           -
#
#       unit price psf date of sale  market segment_CCR  market segment_OCR  \
# 9727          1035.0     Nov-2016                   0                   1
#
#       market segment_RCR  postal district_2.0  postal district_3.0  \
# 9727                   0                    0                    0
#
#       postal district_4.0  postal district_5.0  postal district_8.0  \
# 9727                    0                    0                    0
#
#       postal district_9.0  postal district_10.0  postal district_11.0  \
# 9727                    0                     0                     0
#
#       postal district_12.0  postal district_13.0  postal district_14.0  \
# ...

# %%
merged_house1.shape
# Out:
# (9726, 43)

# %% [markdown]
# ### look into top 2.5% and bottom 2.5%

# %%
(2.5/100 * 9728)/2
# Out:
# 121.60000000000001

# %% [markdown]
# remove top 121 and bottom 121

# %%
biggest = merged_house1.nlargest(119,'unit price psf', keep ='all')

# %%
smallest = merged_house1.nsmallest(121,'unit price psf', keep ='all')

# %%
biggest.shape
# Out:
# (119, 43)

# %%
smallest.shape
# Out:
# (121, 43)

# %%
smallest.tail()
# Out:
#       index                project name        street name  tenure  \
# 7821   7821  LANDED HOUSING DEVELOPMENT    BEECHWOOD GROVE      73
# 8202   8202               WESTWOOD PARK  WESTWOOD CRESCENT      72
# 9013   9013  LANDED HOUSING DEVELOPMENT     SUNRISE AVENUE      73
# 7685   7685  LANDED HOUSING DEVELOPMENT      JALAN GELEGAR     999
# 9017   9017               SARACA VILLAS     SARACA TERRACE      75
#
#      type of sale  no. of units      price nett price  areasq type of area  \
# 7821       Resale           1.0  3400000.0          -  6135.0         Land
# 8202       Resale           1.0   900000.0          -  1615.0         Land
# 9013       Resale           1.0  1690000.0          -  3034.0         Land
# 7685       Resale           1.0  2380000.0          -  4265.0         Land
# 9017       Resale           1.0  2150000.0          -  3806.0         Land
#
#      floor level  unit price psf date of sale  market segment_CCR  \
# ...

# %%
merged_house2 = merged_house1.copy(deep = True)

# %%
merged_house2.shape
# Out:
# (9726, 43)

# %% [markdown]
# # Arrange houseprices by descending order

# %%
merged_house2 = merged_house2.sort_values(by = ['unit price psf'], ascending = False)

# %%
merged_house2.head()
# Out:
#      index                    project name        street name  tenure  \
# 461    461      LANDED HOUSING DEVELOPMENT      SAUNDERS ROAD     999
# 497    497  EMERALD HILL CONSERVATION AREA  EMERALD HILL ROAD     999
# 639    639      LANDED HOUSING DEVELOPMENT  EMERALD HILL ROAD     999
# 330    330  EMERALD HILL CONSERVATION AREA  EMERALD HILL ROAD     999
# 498    498  EMERALD HILL CONSERVATION AREA  EMERALD HILL ROAD     999
#
#     type of sale  no. of units       price nett price  areasq type of area  \
# 461       Resale           1.0  10600000.0          -  2234.0         Land
# 497       Resale           1.0   6680000.0          -  1520.0         Land
# 639       Resale           1.0   5600000.0          -  1281.0         Land
# 330       Resale           1.0   5800000.0          -  1330.0         Land
# 498       Resale           1.0   8280000.0          -  1901.0         Land
#
#     floor level  unit price psf date of sale  market segment_CCR  \
# ...

# %%
merged_house2.drop(['index'], axis=1, inplace = True)

# %%
merged_house2.head()
# Out:
#                        project name        street name  tenure type of sale  \
# 461      LANDED HOUSING DEVELOPMENT      SAUNDERS ROAD     999       Resale
# 497  EMERALD HILL CONSERVATION AREA  EMERALD HILL ROAD     999       Resale
# 639      LANDED HOUSING DEVELOPMENT  EMERALD HILL ROAD     999       Resale
# 330  EMERALD HILL CONSERVATION AREA  EMERALD HILL ROAD     999       Resale
# 498  EMERALD HILL CONSERVATION AREA  EMERALD HILL ROAD     999       Resale
#
#      no. of units       price nett price  areasq type of area floor level  \
# 461           1.0  10600000.0          -  2234.0         Land           -
# 497           1.0   6680000.0          -  1520.0         Land           -
# 639           1.0   5600000.0          -  1281.0         Land           -
# 330           1.0   5800000.0          -  1330.0         Land           -
# 498           1.0   8280000.0          -  1901.0         Land           -
#
# ...

# %%
merged_house2.reset_index(drop = True , inplace = True)

# %%
merged_house2.head()
# Out:
#                      project name        street name  tenure type of sale  \
# 0      LANDED HOUSING DEVELOPMENT      SAUNDERS ROAD     999       Resale
# 1  EMERALD HILL CONSERVATION AREA  EMERALD HILL ROAD     999       Resale
# 2      LANDED HOUSING DEVELOPMENT  EMERALD HILL ROAD     999       Resale
# 3  EMERALD HILL CONSERVATION AREA  EMERALD HILL ROAD     999       Resale
# 4  EMERALD HILL CONSERVATION AREA  EMERALD HILL ROAD     999       Resale
#
#    no. of units       price nett price  areasq type of area floor level  \
# 0           1.0  10600000.0          -  2234.0         Land           -
# 1           1.0   6680000.0          -  1520.0         Land           -
# 2           1.0   5600000.0          -  1281.0         Land           -
# 3           1.0   5800000.0          -  1330.0         Land           -
# 4           1.0   8280000.0          -  1901.0         Land           -
#
#    unit price psf date of sale  market segment_CCR  market segment_OCR  \
# ...

# %%
merged_house2.reset_index(drop = False , inplace = True)

# %%
merged_house2.shape
# Out:
# (9726, 43)

# %%
merged_house2.head()
# Out:
#    index                    project name        street name  tenure  \
# 0      0      LANDED HOUSING DEVELOPMENT      SAUNDERS ROAD     999
# 1      1  EMERALD HILL CONSERVATION AREA  EMERALD HILL ROAD     999
# 2      2      LANDED HOUSING DEVELOPMENT  EMERALD HILL ROAD     999
# 3      3  EMERALD HILL CONSERVATION AREA  EMERALD HILL ROAD     999
# 4      4  EMERALD HILL CONSERVATION AREA  EMERALD HILL ROAD     999
#
#   type of sale  no. of units       price nett price  areasq type of area  \
# 0       Resale           1.0  10600000.0          -  2234.0         Land
# 1       Resale           1.0   6680000.0          -  1520.0         Land
# 2       Resale           1.0   5600000.0          -  1281.0         Land
# 3       Resale           1.0   5800000.0          -  1330.0         Land
# 4       Resale           1.0   8280000.0          -  1901.0         Land
#
#   floor level  unit price psf date of sale  market segment_CCR  \
# ...

# %%
merged_house2.tail()
# Out:
#       index                project name       street name  tenure  \
# 9721   9721  LANDED HOUSING DEVELOPMENT        BEDOK ROAD      13
# 9722   9722  LANDED HOUSING DEVELOPMENT  LORONG 3 GEYLANG       0
# 9723   9723  LANDED HOUSING DEVELOPMENT  LORONG 3 GEYLANG       0
# 9724   9724  LANDED HOUSING DEVELOPMENT  LORONG 3 GEYLANG       0
# 9725   9725  LANDED HOUSING DEVELOPMENT  LORONG 3 GEYLANG       0
#
#      type of sale  no. of units     price nett price  areasq type of area  \
# 9721       Resale           1.0  428000.0          -  4299.0         Land
# 9722       Resale           1.0   50000.0          -   725.0         Land
# 9723       Resale           1.0   50000.0          -   853.0         Land
# 9724       Resale           1.0   40000.0          -   725.0         Land
# 9725       Resale           1.0   63000.0          -  1911.0         Land
#
#      floor level  unit price psf date of sale  market segment_CCR  \
# ...

# %% [markdown]
# ### Find the distribution of the price 1st
#
# Minus the top 118 (119 rows 'highest value') and minus off the bottom (121 rows 'lowest value')

# %%
unitprice = merged_house2['unit price psf']

plt.hist(unitprice, bins =5)
# Out:
# (array([1848., 6935.,  872.,   51.,   20.]),
#  array([  33. ,  975.6, 1918.2, 2860.8, 3803.4, 4746. ]),
#  <BarContainer object of 5 artists>)

# %% [markdown]
# By quantile range, the standard housing price fall in the 1000 - 2000 amount range
#
# The first deduction will be to minus the top 118 (119 rows 'highest value') and minus off the bottom (121 rows 'lowest value').
#
# However, after looking at the heads and tail merged_house2, we should set a value from >500 and <3000

# %%
merged_house2 = merged_house2[merged_house2['unit price psf'] <= 3000]

# %%
merged_house2.shape
# Out:
# (9674, 43)

# %%
merged_house2 = merged_house2[merged_house2['unit price psf'] >= 500]

# %%
merged_house2.shape
# Out:
# (9582, 43)

# %% [markdown]
# create a train test split for merged_house2

# %%
X1 = merged_house2.drop(columns = ['unit price psf','price','project name','street name','type of sale','nett price', 'type of area', 'floor level','date of sale', 'index'])
y1 = merged_house2['unit price psf']

# %%
X1.head()
# Out:
#     tenure  no. of units  areasq  market segment_CCR  market segment_OCR  \
# 52     999           1.0  1720.0                   1                   0
# 53     999           1.0  1650.0                   1                   0
# 54     999           1.0   903.0                   0                   0
# 55     999           1.0  2799.0                   1                   0
# 56     999           1.0  3209.0                   1                   0
#
#     market segment_RCR  postal district_2.0  postal district_3.0  \
# 52                   0                    0                    0
# 53                   0                    0                    0
# 54                   1                    0                    0
# 55                   0                    0                    0
# 56                   0                    0                    0
#
#     postal district_4.0  postal district_5.0  postal district_8.0  \
# ...

# %%
X1['no. of units'].value_counts()
# Out:
# 1.0     9562
# 2.0        9
# 3.0        5
# 4.0        2
# 11.0       2
# 5.0        1
# 6.0        1
# Name: no. of units, dtype: int64

# %%
# Create train/test splits.
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size =0.25, random_state=42)

# %%
sc = StandardScaler()
Z1_train = sc.fit_transform(X1_train)
Z1_test = sc.transform(X1_test)

# %%
lr.fit(Z1_train, y1_train);

# %%
lr.score(Z1_train, y1_train)
# Out:
# 0.4393210144663231

# %%
lr.score(Z1_test, y1_test)
# Out:
# 0.4199440392486814

# %%
XGB = XGBRegressor()
XGB.fit(Z1_train, y1_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
XGB.score(Z1_train, y1_train)
# Out:
# 0.7878339744541711

# %%
XGB.score(Z1_test, y1_test)
# Out:
# 0.6157849596960314

# %%
XGB2_params ={
    'max_depth':[3, 4, 5],
    'sub_sample': [0.5, 1],
    'colsample_bytree':[0.5, 1],
    'min_child_weight': [1, 5],
    'reg_lambda':[0.5, 1],
    'reg_alpha':[0.5, 1],
    'n_estimators':[10, 100],
    'learning_rate':[0.1, 1]
}
gs3 = GridSearchCV(XGB, param_grid =XGB2_params, cv = 5, n_jobs =-1)
gs3.fit(Z1_train, y1_train)
gs3.best_params_
# Out:
# [18:57:21] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# {'colsample_bytree': 1,
#  'learning_rate': 0.1,
#  'max_depth': 5,
#  'min_child_weight': 1,
#  'n_estimators': 100,
#  'reg_alpha': 1,
#  'reg_lambda': 1,
#  'sub_sample': 0.5}

# %%
gs3.score(Z1_train, y1_train)
# Out:
# 0.6960768522304462

# %%
gs3.score(Z1_test, y1_test)
# Out:
# 0.6313680712807341

# %%
def xgb2(search):
    colsample_bytree = search.suggest_float("colsample_bytree", 0.1, 1.0)
    learning_rate = search.suggest_float("learning_rate", 0.1, 1.0) 
    max_depth = search.suggest_int("max_depth",1, 5)
    min_child_weight = search.suggest_int("min_child_weight", 1, 5)
    n_estimator = search.suggest_int("n_estimators", 100, 200, 300)
    reg_lambda = search.suggest_loguniform("reg_lambda", 1e-8, 100)
    reg_alpha = search.suggest_loguniform("reg_alpha", 1e-8, 100)
    sub_sample = search.suggest_float("sub_sample", 0.1, 1.0)
    
    model = XGBRegressor(random_state = 42,
                         colsample_bytree = colsample_bytree,
                         learning_rate = learning_rate,
                         max_depth = max_depth,
                         min_child_weight = min_child_weight,
                         n_estimator = n_estimator,
                         reg_lambda = reg_lambda, 
                         reg_alpha = reg_alpha,
                         sub_sample = sub_sample,
                         n_jobs = -1
                        )
    
    score = cross_val_score(model, Z1_train, y1_train, scoring = 'neg_root_mean_squared_error', cv = 5, verbose = 1)
    mean_score = score.mean()
    std_score = score.std()
    
    accuracy = mean_score - std_score
    
    return accuracy

study = optuna.create_study(direction = 'maximize',sampler = TPESampler(seed =42))
study.optimize(xgb2, n_trials=100)
# Out:
# [I 2021-12-09 18:57:22,227] A new study created in memory with name: no-name-5eb10e68-cc00-4000-bb02-7944d23649f3
# C:\Users\jiexi\anaconda3\lib\site-packages\optuna\distributions.py:560: UserWarning: The distribution is specified by [100, 200] and step=300, but the range is not divisible by `step`. It will be replaced by [100, 100].
#   warnings.warn(
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [18:57:22] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:57:22] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# ...

# %%
study.best_params
# Out:
# {'colsample_bytree': 0.43983323399790797,
#  'learning_rate': 0.24402423212833396,
#  'max_depth': 4,
#  'min_child_weight': 2,
#  'n_estimators': 100,
#  'reg_lambda': 1.3516484922476007e-07,
#  'reg_alpha': 33.01842456619386,
#  'sub_sample': 0.6936784258018838}

# %%
study.best_trial.value
# Out:
# -250.27783082018357

# %%
XGB5 = XGBRegressor(colsample_bytree= 0.43983323399790797, learning_rate= 0.24402423212833396, max_depth= 4, min_child_weight= 2, n_estimators= 100,
reg_alpha= 33.01842456619386, reg_lambda= 1.3516484922476007e-07, sub_sample= 0.6936784258018838)
XGB5.fit(Z1_train, y1_train)
# Out:
# [18:59:38] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.43983323399790797,
#              enable_categorical=False, gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.24402423212833396,
#              max_delta_step=0, max_depth=4, min_child_weight=2, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=0,
# ...

# %%
XGB5.score(Z1_train, y1_train)
# Out:
# 0.6918293065589263

# %%
XGB5.score(Z1_test, y1_test)
# Out:
# 0.6309956952519384

# %%
plt.figure(figsize =(8,8))
sns.heatmap(merged_house2.corr()[['unit price psf']].sort_values('unit price psf', ascending =False), annot=True, vmin = -1, vmax = 1, cmap = 'coolwarm');

# %%
X1.head()
# Out:
#     tenure  no. of units  areasq  market segment_CCR  market segment_OCR  \
# 52     999           1.0  1720.0                   1                   0
# 53     999           1.0  1650.0                   1                   0
# 54     999           1.0   903.0                   0                   0
# 55     999           1.0  2799.0                   1                   0
# 56     999           1.0  3209.0                   1                   0
#
#     market segment_RCR  postal district_2.0  postal district_3.0  \
# 52                   0                    0                    0
# 53                   0                    0                    0
# 54                   1                    0                    0
# 55                   0                    0                    0
# 56                   0                    0                    0
#
#     postal district_4.0  postal district_5.0  postal district_8.0  \
# ...

# %%
X1.dtypes.head()
# Out:
# tenure                  int64
# no. of units          float64
# areasq                float64
# market segment_CCR      uint8
# market segment_OCR      uint8
# dtype: object

# %%
merged_house2['no. of units'].value_counts()
# Out:
# 1.0     9562
# 2.0        9
# 3.0        5
# 4.0        2
# 11.0       2
# 5.0        1
# 6.0        1
# Name: no. of units, dtype: int64

# %%
X2 = merged_house2.drop(columns = ['unit price psf','price','project name','street name','type of sale','nett price', 'type of area', 'floor level','date of sale', 'index', 'no. of units'])
y2 = merged_house2['unit price psf']

# %%
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size =0.25, random_state=42)

# %%
Z2_train = sc.fit_transform(X2_train)
Z2_test = sc.transform(X2_test)

# %%
def xgb3(search):
    colsample_bytree = search.suggest_float("colsample_bytree", 0.1, 1.0)
    learning_rate = search.suggest_float("learning_rate", 0.1, 1.0) 
    max_depth = search.suggest_int("max_depth",1, 5)
    min_child_weight = search.suggest_int("min_child_weight", 1, 5)
    n_estimator = search.suggest_int("n_estimators", 100, 200, 300)
    reg_lambda = search.suggest_loguniform("reg_lambda", 1e-8, 100)
    reg_alpha = search.suggest_loguniform("reg_alpha", 1e-8, 100)
    sub_sample = search.suggest_float("sub_sample", 0.1, 1.0)
    
    model = XGBRegressor(random_state = 42,
                         colsample_bytree = colsample_bytree,
                         learning_rate = learning_rate,
                         max_depth = max_depth,
                         min_child_weight = min_child_weight,
                         n_estimator = n_estimator,
                         reg_lambda = reg_lambda, 
                         reg_alpha = reg_alpha,
                         sub_sample = sub_sample,
                         n_jobs = -1
                        )
    
    score = cross_val_score(model, Z2_train, y2_train, scoring = 'neg_root_mean_squared_error', cv = 5, verbose = 1)
    mean_score = score.mean()
    std_score = score.std()
    
    accuracy = mean_score - std_score
    
    return accuracy

study = optuna.create_study(direction = 'maximize',sampler = TPESampler(seed =42))
study.optimize(xgb3, n_trials=100)
# Out:
# [I 2021-12-09 18:59:39,668] A new study created in memory with name: no-name-38dfcd6a-2b5e-4d1e-a80f-c2051b805584
# C:\Users\jiexi\anaconda3\lib\site-packages\optuna\distributions.py:560: UserWarning: The distribution is specified by [100, 200] and step=300, but the range is not divisible by `step`. It will be replaced by [100, 100].
#   warnings.warn(
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [18:59:39] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:59:39] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# ...

# %%
study.best_params
# Out:
# {'colsample_bytree': 0.831421769168034,
#  'learning_rate': 0.36380387452961305,
#  'max_depth': 5,
#  'min_child_weight': 4,
#  'n_estimators': 100,
#  'reg_lambda': 24.668668436811082,
#  'reg_alpha': 4.323279330292776,
#  'sub_sample': 0.6657752545926474}

# %%
study.best_trial.value
# Out:
# -251.2431146136163

# %%
XGB6 = XGBRegressor(colsample_bytree=  0.831421769168034, learning_rate= 0.36380387452961305, max_depth= 5, min_child_weight= 4, n_estimators= 100,
reg_alpha= 4.323279330292776, reg_lambda= 24.668668436811082, sub_sample= 0.6657752545926474)
XGB6.fit(Z2_train, y2_train)
# Out:
# [19:02:03] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.831421769168034,
#              enable_categorical=False, gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.36380387452961305,
#              max_delta_step=0, max_depth=5, min_child_weight=4, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=0,
# ...

# %%
XGB6.score(Z2_train, y2_train)
# Out:
# 0.7058537577368333

# %%
XGB6.score(Z2_test, y2_test)
# Out:
# 0.6328242860842839

# %%
y_pred2 = XGB6.predict(Z2_train)

# %%
np.sqrt(metrics.mean_squared_error(y2_train, y_pred2))
# Out:
# 222.85785823184537

# %% [markdown]
# ### will remove +2 of higher price psf

# %%
#merged_house2 = merged_house2['unit price psf'].between(merged_house2['unit price psf'].quantile(0.025), merged_house2['unit price psf'].quantile(0.975))

# %%
merged_house2.head()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: unit price psf, dtype: bool

# %%
merged_house = merged_house[merged_house['unit price psf'] <= 5000]

# %% [markdown]
# more visualization, like sgmap and postal district
