# %% [markdown]
# # Problem statement: To Predict the Prices of private residential properties.

# %% [markdown]
# This workbook will be used for modelling

# %% [markdown]
# ## Content
# - [Data Modelling](#Data-Modelling)
#     - [Data Modelling for 5% data removed](#Data-Modelling-for-5%-data-removed)
#         - [Linear Regression for 5% data removed](#Linear-Regression-for-5%-data-removed)
#         - [Lasso Regression for 5% data removed](#Lasso-Regression-for-5%-data-removed)
#         - [Check for colinearity](#Check-for-colinearity)
#         - [XGBoost Regressor for 5% data removed](#XGBoost-Regressor-for-5%-data-removed)
#         - [Random Forest Regressor for 5% data removed](#Random-Forest-Regressor-for-5%-data-removed)
# - [Overview for 5% data removed](#Overview-for-5%-data-removed)
#     - [Data Modelling for 10% data removed](#Data-Modelling-for-10%-data-removed)
#         - [Linear Regression for 10% data removed](#Linear-Regression-for-10%-data-removed)
#         - [XGBoost Regressor for 10% data removed](#XGBoost-Regressor-for-10%-data-removed)
#         - [Random Forest Regressor for 10% data removed](#Random-Forest-Regressor-for-10%-data-removed)
#         - [Overview for 10% data removed](#Overview-for-10%-data-removed)
# - [Splitting of dataset](#Splitting-of-dataset)
#      - [Dataset with houses tenure <=99years](#Dataset-with-houses-tenure-<=99years)
#      - [Dataset with houses tenure categorized as freehold](#Dataset-with-houses-tenure-categorized-as-freehold)
# - [Conclusion](#Conclusion)

# %%
import pandas as pd
import numpy as np
import pylab
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns
import re
import optuna
import warnings
from optuna.samplers import TPESampler
from xgboost import XGBRegressor

from sklearn.preprocessing import OrdinalEncoder, StandardScaler
from sklearn import metrics,linear_model
from sklearn.metrics import accuracy_score, mean_squared_error
from sklearn.ensemble import RandomForestRegressor 
from sklearn.tree import DecisionTreeRegressor

from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.linear_model import LinearRegression,Lasso

# %%
# To clean off the errors in seaborn and matplotlib
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data Modelling

# %% [markdown]
# ## Data Modelling for 5% data removed

# %%
merged_house_data = pd.read_csv('./dataset_asof_051121/merged_house_data.csv')

# %%
merged_house_data.shape
# Out:
# (9240, 45)

# %% [markdown]
# To look for the average error RMSE score

# %%
merged_house_data['average'] =merged_house_data.price.mean()

# %%
# This is a random prediction by predicting all observation by the mean of the training set, ML model RMSE should be better than this average values
np.round(mean_squared_error(merged_house_data['price'], merged_house_data['average'], squared = False))
# Out:
# 2355449.0

# %%
merged_house_data.head(1)
# Out:
#    index                project name   street name  tenure  no. of units  \
# 0      0  LANDED HOUSING DEVELOPMENT  PEARL ISLAND      86           1.0
#
#         price nett price  areasq type of area floor level  ...  \
# 0  16550000.0          -  8940.0         Land           -  ...
#
#    postal district_26.0 postal district_27.0  postal district_28.0  \
# 0                     0                    0                     0
#
#    type_Detached  type_Semi-detached  type_Terrace  type of sale_New Sale  \
# 0              1                   0             0                      0
#
#    type of sale_Resale  type of sale_Sub Sale       average
# 0                    1                      0  3.974609e+06
#
# [1 rows x 46 columns]

# %%
#drop the baseline column
merged_house_data =merged_house_data.drop('average', axis = 1)

# %%
sns.set(font_scale=1)
plt.figure(figsize =(5,10))
sns.heatmap(merged_house_data.corr()[['price']].sort_values('price', ascending =False), annot=True, vmin = -1, vmax = 1, cmap = 'coolwarm');

# %%
pd.set_option('max_columns',None)

# %% [markdown]
# ## Linear Regression for 5% data removed

# %%
X = merged_house_data.drop(columns =['price', 'unit price psf', 'index', 'project name', 'street name', 'nett price', 'type of area','floor level','date of sale',])
y = merged_house_data['price']

# %%
# Create train/test splits.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size =0.25, random_state=42)

# %% [markdown]
# ### Using Standardscalar as values in the features have huge values apart, dummified and exact interger values

# %%
sc = StandardScaler()
Z_train = sc.fit_transform(X_train)
Z_test = sc.transform(X_test)

# %%
# instantiate the model
lr = LinearRegression()
#fit using the training data
lr.fit(Z_train, y_train);

# %% [markdown]
# ### Doing a check on the MSE/RMSE on between the train and the predicted values from test

# %%
def print_result(model,X_train,X_test, y_train, y_test, title):
    print(title)
    
    print('\nAverage Score RMSE is 2355449')
    #Training Score
    print('\nTrain Score')
    y_pred_train = model.predict(X_train)
    
    train_mse = int(metrics.mean_squared_error(y_train, y_pred_train))
    train_rmse = int(np.sqrt(metrics.mean_squared_error(y_train, y_pred_train)))
    print("MSE IS {}".format(train_mse))
    print("RSME IS {}".format(train_rmse))
    
    #Test Score
    print('\nTest')
    y_pred_test = model.predict(X_test)
    test_mse = int(metrics.mean_squared_error(y_test, y_pred_test))
    test_rmse = int(np.sqrt(metrics.mean_squared_error(y_test, y_pred_test)))
    
    print("MSE IS {}".format(test_mse))
    print("RSME IS {}".format(test_rmse))
    
    #%percentage difference
    print(('\nTrain Test % Difference'))
    print(f'{round((test_rmse - train_rmse)/test_rmse * 100,2)}%')

# %% [markdown]
# ### Compare train and test RMSE apart

# %%
print_result(model=lr,
            X_train = Z_train,
             X_test = Z_test,
             y_train = y_train,
             y_test = y_test,
            title='Comparison of Model Train Test & Average Score')
# Out:
# Comparison of Model Train Test & Average Score
#
# Average Score RMSE is 2355449
#
# Train Score
# MSE IS 887617750885
# RSME IS 942134
#
# Test
# MSE IS 1008977094445
# RSME IS 1004478
#
# Train Test % Difference
# 6.21%

# %% [markdown]
# ### Overfitting from Linear Regression, to check with Lasso Regression whether the number of features is causing the overfit.

# %% [markdown]
# ## Lasso Regression for 5% data removed

# %% [markdown]
# Using Lasso Regression to check on features that may cause an overfit

# %%
# State the parameters you want to search for lasso regularisation
# we want to go through 10000, 50000, 100000 different alpha values
parameters = {
                'alpha': [10000, 50000, 100000]
             }

# Instantiate the model
lasso = Lasso()

# Instantiate Gridsearch (use previous instantiated parameters and model)
lasso_lr = GridSearchCV(lasso, parameters, 
                     scoring='neg_mean_squared_error', 
                     cv=5, verbose=1, n_jobs=-1)

# %%
lasso_lr.fit(Z_train, y_train);
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits

# %%
print(lasso_lr.best_params_)
# Out:
# {'alpha': 10000}

# %%
lasso_reg = linear_model.Lasso(alpha = 10000, max_iter=10000000, tol=0.1)

# %%
lasso_reg.fit(Z_train, y_train)
# Out:
# Lasso(alpha=10000, max_iter=10000000, tol=0.1)

# %% [markdown]
# ### Compare train and test RMSE apart

# %%
print_result(model=lasso_reg,
            X_train = Z_train,
             X_test = Z_test,
             y_train = y_train,
             y_test = y_test,
            title='Comparison of Model Train Test & Average Score')
# Out:
# Comparison of Model Train Test & Average Score
#
# Average Score RMSE is 2355449
#
# Train Score
# MSE IS 910663332604
# RSME IS 954286
#
# Test
# MSE IS 1028266666030
# RSME IS 1014034
#
# Train Test % Difference
# 5.89%

# %% [markdown]
# ## Check for colinearity

# %%
merged_house_data[['tenure', 'no. of units','areasq']].corr()
#There is not much corelation between the features
# Out:
#                 tenure  no. of units    areasq
# tenure        1.000000      0.008888  0.107167
# no. of units  0.008888      1.000000  0.082425
# areasq        0.107167      0.082425  1.000000

# %%
merged_house_data[['tenure', 'no. of units','areasq','type_Detached', 'type_Semi-detached','type_Terrace','price']].corr()
# Area sq is the most related to the price of the houses, we can see under type_detached that is also related, 
# the ascending classification of grade of houses should be terrace, semi-detached follwoed by detached, these features should be included during feature engineering
# Out:
#                       tenure  no. of units    areasq  type_Detached  \
# tenure              1.000000      0.008888  0.107167       0.042907
# no. of units        0.008888      1.000000  0.082425       0.015809
# areasq              0.107167      0.082425  1.000000       0.722404
# type_Detached       0.042907      0.015809  0.722404       1.000000
# type_Semi-detached  0.005661     -0.002381  0.147510      -0.237468
# type_Terrace       -0.032755     -0.007891 -0.600283      -0.417887
# price               0.217158      0.061880  0.809494       0.677885
#
#                     type_Semi-detached  type_Terrace     price
# tenure                        0.005661     -0.032755  0.217158
# no. of units                 -0.002381     -0.007891  0.061880
# areasq                        0.147510     -0.600283  0.809494
# type_Detached                -0.237468     -0.417887  0.677885
# type_Semi-detached            1.000000     -0.783277  0.118857
# type_Terrace                 -0.783277      1.000000 -0.544994
# price                         0.118857     -0.544994  1.000000

# %%
merged_house_data[['market segment_CCR', 'market segment_OCR','market segment_RCR', 'price']].corr()
#OCR seems to be slightly co-related to RCR, this is expected as CCR and RCR prices will fetch more, however for RCR, there is not much co -relation
# Out:
#                     market segment_CCR  market segment_OCR  \
# market segment_CCR            1.000000           -0.567501
# market segment_OCR           -0.567501            1.000000
# market segment_RCR           -0.183527           -0.705236
# price                         0.506760           -0.367331
#
#                     market segment_RCR     price
# market segment_CCR           -0.183527  0.506760
# market segment_OCR           -0.705236 -0.367331
# market segment_RCR            1.000000  0.002202
# price                         0.002202  1.000000

# %% [markdown]
# ### Next, when performing linear regression, we need to check for multi- regression assumptions
#
# Linearity: The mean values of the outcome variable for each increment of the predictor(s) lie along a straight line. In other words, there is a linear relationship between predictors and target.
#
# No perfect multicollinearity: There should be no perfect linear relationship between two or more of the predictors.
#
# Normally distributed errors: the residuals are random, normally distributed with a mean of 0.
#
# Homoscedasticity: The variance of the residual terms should be constant.

# %%
#Refit selected lasso model
y_pred_lasso_test =lasso_reg.predict(Z_test)

# Visualizing actual prices vs predicted values
plt.scatter(y_test, y_pred_lasso_test)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual Cost Price vs Predicted Cost Price")
plt.show()

# %%
# Residual vs fit plot
plt.scatter(y_pred_lasso_test, y_test - y_pred_lasso_test)
plt.title("Residual vs Fit Plot")
plt.xlabel("Predicted")
plt.ylabel("Residuals")
plt.show()

# %% [markdown]
# The lasso regression model
#
# We can see that there is an increase variance as the predicted value increase, this shows that the relationship is not linear.

# %% [markdown]
# ## XGBoost Regressor for 5% data removed

# %%
XGB = XGBRegressor()

# %%
def xgb(search):
    colsample_bytree = search.suggest_float("colsample_bytree", 0.1, 1.0)
    learning_rate = search.suggest_float("learning_rate", 0.1, 1.0) 
    max_depth = search.suggest_int("max_depth",1, 5)
    min_child_weight = search.suggest_int("min_child_weight", 1, 5)
    n_estimator = search.suggest_int("n_estimators", 100, 300)
    reg_lambda = search.suggest_loguniform("reg_lambda", 1e-8, 100)
    reg_alpha = search.suggest_loguniform("reg_alpha", 1e-8, 100)
    sub_sample = search.suggest_float("sub_sample", 0.1, 1.0)
    
    model = XGBRegressor(random_state = 42,
                         colsample_bytree = colsample_bytree,
                         learning_rate = learning_rate,
                         max_depth = max_depth,
                         min_child_weight = min_child_weight,
                         n_estimator = n_estimator,
                         reg_lambda = reg_lambda, 
                         reg_alpha = reg_alpha,
                         sub_sample = sub_sample,
                         n_jobs = -1
                        )
    
    score = cross_val_score(model, Z_train, y_train, scoring = 'neg_root_mean_squared_error', cv = 5, verbose = 1)
    mean_score = score.mean()
    std_score = score.std()
    
    accuracy = mean_score - std_score
    
    return accuracy

study = optuna.create_study(direction = 'maximize', sampler = TPESampler(seed =42))
study.optimize(xgb, n_trials=100)
# Out:
# [I 2022-01-23 18:43:25,507] A new study created in memory with name: no-name-20f585da-ae94-4146-ac69-6e71888a7044
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [18:43:25] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:43:25] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:43:25] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:43:25] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.5s finished
# [I 2022-01-23 18:43:26,086] Trial 0 finished with value: -947877.5843474511 and parameters: {'colsample_bytree': 0.4370861069626263, 'learning_rate': 0.9556428757689246, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 131, 'reg_lambda': 3.6303224667798554e-07, 'reg_alpha': 3.809220577048033e-08, 'sub_sample': 0.8795585311974417}. Best is trial 0 with value: -947877.5843474511.
# [18:43:25] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:43:26] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:43:26] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.2s finished
# [I 2022-01-23 18:43:26,391] Trial 1 finished with value: -977752.6290902907 and parameters: {'colsample_bytree': 0.6410035105688879, 'learning_rate': 0.737265320016441, 'max_depth': 1, 'min_child_weight': 5, 'n_estimators': 267, 'reg_lambda': 1.3285903900544182e-06, 'reg_alpha': 6.580360277501306e-07, 'sub_sample': 0.2650640588680905}. Best is trial 0 with value: -947877.5843474511.
# [18:43:26] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:43:26] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:43:26] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [18:43:26] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:43:26] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:43:26] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:43:26] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:43:26] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.4s finished
# [I 2022-01-23 18:43:26,856] Trial 2 finished with value: -869995.3307118821 and parameters: {'colsample_bytree': 0.373818018663584, 'learning_rate': 0.5722807884690141, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 222, 'reg_lambda': 2.4827821051950883e-07, 'reg_alpha': 8.345387083873532e-06, 'sub_sample': 0.4297256589643226}. Best is trial 2 with value: -869995.3307118821.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [18:43:26] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:43:26] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:43:26] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:43:27] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.2s finished
# [I 2022-01-23 18:43:27,140] Trial 3 finished with value: -978282.8602361236 and parameters: {'colsample_bytree': 0.5104629857953323, 'learning_rate': 0.8066583652537123, 'max_depth': 1, 'min_child_weight': 3, 'n_estimators': 219, 'reg_lambda': 2.9140978279786215e-08, 'reg_alpha': 0.011897302909454906, 'sub_sample': 0.2534717113185624}. Best is trial 2 with value: -869995.3307118821.
# [18:43:27] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:43:27] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:43:27] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [18:43:27] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:43:27] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:43:27] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.4s finished
# [I 2022-01-23 18:43:27,607] Trial 4 finished with value: -907379.968428757 and parameters: {'colsample_bytree': 0.1585464336867516, 'learning_rate': 0.9539969835279999, 'max_depth': 5, 'min_child_weight': 5, 'n_estimators': 161, 'reg_lambda': 9.478096804784244e-08, 'reg_alpha': 0.06955530592645753, 'sub_sample': 0.4961372443656412}. Best is trial 2 with value: -869995.3307118821.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [18:43:27] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:43:27] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:43:27] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:43:27] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.2s finished
# [I 2022-01-23 18:43:27,887] Trial 5 finished with value: -1023059.177903133 and parameters: {'colsample_bytree': 0.20983441136030095, 'learning_rate': 0.5456592191001431, 'max_depth': 1, 'min_child_weight': 5, 'n_estimators': 152, 'reg_lambda': 0.042191293826476094, 'reg_alpha': 1.3095158546031483e-05, 'sub_sample': 0.5680612190600297}. Best is trial 2 with value: -869995.3307118821.
# [18:43:27] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:43:27] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:43:28] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [18:43:28] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:43:28] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.6s finished
# [I 2022-01-23 18:43:28,588] Trial 6 finished with value: -849232.7262238595 and parameters: {'colsample_bytree': 0.5920392514089517, 'learning_rate': 0.26636900997297436, 'max_depth': 5, 'min_child_weight': 4, 'n_estimators': 288, 'reg_lambda': 8.8771488946556, 'reg_alpha': 0.00952795699161383, 'sub_sample': 0.9296868115208051}. Best is trial 6 with value: -849232.7262238595.
# [18:43:28] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:43:28] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:43:28] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.1s finished
# [I 2022-01-23 18:43:28,841] Trial 7 finished with value: -1050371.4158046818 and parameters: {'colsample_bytree': 0.17964325184672755, 'learning_rate': 0.27638457617723067, 'max_depth': 1, 'min_child_weight': 2, 'n_estimators': 178, 'reg_lambda': 5.169997317292732e-06, 'reg_alpha': 1.9380951355796903, 'sub_sample': 0.4210779940242304}. Best is trial 6 with value: -849232.7262238595.
# [18:43:28] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:43:28] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:43:28] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:43:28] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:43:28] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.2s finished
# [I 2022-01-23 18
 'max_depth': 2, 'min_child_weight': 3, 'n_estimators': 279, 'reg_lambda': 0.003946016809606652, 'reg_alpha': 0.10895761268128272, 'sub_sample': 0.8841430043100764}. Best is trial 6 with value: -849232.7262238595.
# [18:43:35] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:43:35] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [18:43:35] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:43:35] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:43:35] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
# ...
# [I 2022-01-23 18:44:19,810] Trial 93 finished with value: -843760.9487180145 and parameters: {'colsample_bytree': 0.413740633693629, 'learning_rate': 0.19262834849028565, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 114, 'reg_lambda': 0.00042874345571846826, 'reg_alpha': 0.03621274043868008, 'sub_sample': 0.3553158932951884}. Best is trial 40 with value: -839211.07246092.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [18:44:19] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:44:19] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:44:20] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:44:20] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.5s finished
# [I 2022-01-23 18:44:20,418] Trial 94 finished with value: -845692.9555276454 and parameters: {'colsample_bytree': 0.4830878470276895, 'learning_rate': 0.22957131306800854, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 105, 'reg_lambda': 0.00018915551950539968, 'reg_alpha': 0.012302418238259694, 'sub_sample': 0.4067948770755706}. Best is trial 40 with value: -839211.07246092.
# [18:44:20] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:44:20] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [18:44:20] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:44:20] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:44:20] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:44:20] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.5s finished
# [I 2022-01-23 18:44:21,030] Trial 95 finished with value: -848438.1161800519 and parameters: {'colsample_bytree': 0.43497678129324907, 'learning_rate': 0.11218753978640242, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 143, 'reg_lambda': 0.013618092679473694, 'reg_alpha': 0.0023832096818669477, 'sub_sample': 0.15251591824156013}. Best is trial 40 with value: -839211.07246092.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [18:44:21] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:44:21] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:44:21] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:44:21] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.2s finished
# [I 2022-01-23 18:44:21,334] Trial 96 finished with value: -991736.8966949882 and parameters: {'colsample_bytree': 0.3371319160665911, 'learning_rate': 0.279395912588154, 'max_depth': 1, 'min_child_weight': 2, 'n_estimators': 202, 'reg_lambda': 0.0011638779719117978, 'reg_alpha': 8.075893083044014e-05, 'sub_sample': 0.27297852016204416}. Best is trial 40 with value: -839211.07246092.
# [18:44:21] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:44:21] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:44:21] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [18:44:21] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:44:21] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.4s finished
# [I 2022-01-23 18:44:21,923] Trial 97 finished with value: -844173.008452178 and parameters: {'colsample_bytree': 0.3959030168842368, 'learning_rate': 0.1699467479168408, 'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 119, 'reg_lambda': 2.0190306102327074e-05, 'reg_alpha': 0.00407058825643798, 'sub_sample': 0.21276423673633466}. Best is trial 40 with value: -839211.07246092.
# [18:44:21] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:44:21] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [18:44:22] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:44:22] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:44:22] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.4s finished
# [I 2022-01-23 18:44:22,438] Trial 98 finished with value: -857355.7412220293 and parameters: {'colsample_bytree': 0.45796447383390226, 'learning_rate': 0.14103429320523894, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 112, 'reg_lambda': 0.00011303227456612316, 'reg_alpha': 0.1491377377504677, 'sub_sample': 0.2532712813828924}. Best is trial 40 with value: -839211.07246092.
# [18:44:22] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:44:22] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [18:44:22] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:44:22] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.4s finished
# [I 2022-01-23 18:44:22,979] Trial 99 finished with value: -850965.352839872 and parameters: {'colsample_bytree': 0.28126662097613453, 'learning_rate': 0.25020646479177766, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 123, 'reg_lambda': 6.70371507068887e-07, 'reg_alpha': 8.213018060411023e-06, 'sub_sample': 0.10265080073421462}. Best is trial 40 with value: -839211.07246092.
# [18:44:22] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:44:22] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.

# %%
study.best_params
# Out:
# {'colsample_bytree': 0.3210453302143611,
#  'learning_rate': 0.3202090726592401,
#  'max_depth': 4,
#  'min_child_weight': 5,
#  'n_estimators': 209,
#  'reg_lambda': 0.06671435437091235,
#  'reg_alpha': 1.4470092001124865e-05,
#  'sub_sample': 0.10335355878436842}

# %%
XGB = XGBRegressor(**study.best_params)
XGB.fit(Z_train, y_train);
# Out:
# [18:44:23] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.

# %% [markdown]
# ### Compare train and test RMSE apart

# %%
print_result(model= XGB,
            X_train = Z_train,
             X_test = Z_test,
             y_train = y_train,
             y_test = y_test,
            title='Comparison of Model Train Test & Average Score')
# Out:
# Comparison of Model Train Test & Average Score
#
# Average Score RMSE is 2355449
#
# Train Score
# MSE IS 475451948549
# RSME IS 689530
#
# Test
# MSE IS 745000806075
# RSME IS 863134
#
# Train Test % Difference
# 20.11%

# %% [markdown]
# ### This indicates that XGBoost is overfitted

# %% [markdown]
# ## Random Forest Regressor for 5% data removed

# %%
rf = RandomForestRegressor(random_state=42)

# %%
# Gridseach done multiple times to narrow in the best params
rf_params = {
    'n_estimators': [180, 200, 210, 220, 250],
    'max_depth': [4, 7, 9, 12],
}
rf5 = GridSearchCV(rf, param_grid=rf_params, cv=5, n_jobs=-1)
rf5.fit(Z_train, y_train)
rf5.best_params_
# Out:
# {'max_depth': 9, 'n_estimators': 220}

# %% [markdown]
# ### Comparing of train and test RMSE of RFRegressor

# %%
print_result(model= rf5,
            X_train = Z_train,
             X_test = Z_test,
             y_train = y_train,
             y_test = y_test,
            title='Comparison of Model Train Test & Baseline Score')
# Out:
# Comparison of Model Train Test & Baseline Score
#
# Average Score RMSE is 2355449
#
# Train Score
# MSE IS 439913286538
# RSME IS 663259
#
# Test
# MSE IS 790225740601
# RSME IS 888946
#
# Train Test % Difference
# 25.39%

# %% [markdown]
# ## Overview for 5% data removed

# %% [markdown]
# There are overfitting for linear regression, lasso regression, XGBoost as well as Random Forest Regressor. Hence, the dataset was further reduced by another 5% (total of 10% removed).

# %% [markdown]
# ## Data Modelling for 10% data removed

# %%
merged_house_10 = pd.read_csv('./dataset_asof_051121/merged_house_10.csv')

# %%
merged_house_10.shape
# Out:
# (8753, 45)

# %% [markdown]
# ## Linear Regression for 10% data removed

# %%
X10 = merged_house_10.drop(columns =['price', 'unit price psf', 'index', 'project name', 'street name', 'nett price', 'type of area','floor level','date of sale',])
y10 = merged_house_10['price']

# %%
X10_train, X10_test, y10_train, y10_test = train_test_split(X10, y10, test_size =0.25, random_state=42)

# %%
Z10_train = sc.fit_transform(X10_train)
Z10_test = sc.transform(X10_test)

# %%
lr10 = LinearRegression()

# %%
lr10.fit(Z10_train, y10_train);

# %%
print_result(model= lr10,
            X_train = Z10_train,
             X_test = Z10_test,
             y_train = y10_train,
             y_test = y10_test,
            title='Comparison of Model Train Test & Average Score')
# Out:
# Comparison of Model Train Test & Average Score
#
# Average Score RMSE is 2355449
#
# Train Score
# MSE IS 639008548114
# RSME IS 799380
#
# Test
# MSE IS 745082847995
# RSME IS 863181
#
# Train Test % Difference
# 7.39%

# %% [markdown]
# ### This indicates that Linear regression fo 10% dataset removed is still overfitted

# %% [markdown]
# ## XGBoost Regressor for 10% data removed

# %%
def xgb(search):
    colsample_bytree = search.suggest_float("colsample_bytree", 0.1, 1.0)
    learning_rate = search.suggest_float("learning_rate", 0.1, 1.0) 
    max_depth = search.suggest_int("max_depth",1, 5)
    min_child_weight = search.suggest_int("min_child_weight", 1, 5)
    n_estimator = search.suggest_int("n_estimators", 100, 300)
    reg_lambda = search.suggest_loguniform("reg_lambda", 1e-8, 100)
    reg_alpha = search.suggest_loguniform("reg_alpha", 1e-8, 100)
    sub_sample = search.suggest_float("sub_sample", 0.1, 1.0)
    
    model = XGBRegressor(random_state = 42,
                         colsample_bytree = colsample_bytree,
                         learning_rate = learning_rate,
                         max_depth = max_depth,
                         min_child_weight = min_child_weight,
                         n_estimator = n_estimator,
                         reg_lambda = reg_lambda, 
                         reg_alpha = reg_alpha,
                         sub_sample = sub_sample,
                         n_jobs = -1
                        )
    
    score = cross_val_score(model, Z10_train, y10_train, scoring = 'neg_root_mean_squared_error', cv = 5, verbose = 1)
    mean_score = score.mean()
    std_score = score.std()
    
    accuracy = mean_score - std_score
    
    return accuracy

study = optuna.create_study(direction = 'maximize', sampler = TPESampler(se
 'max_depth': 5, 'min_child_weight': 4, 'n_estimators': 291, 'reg_lambda': 2.6116094684418244e-06, 'reg_alpha': 2.5691344993786866e-07, 'sub_sample': 0.8950504013525614}. Best is trial 91 with value: -708176.1656207722.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [18:45:56] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:45:56] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:45:56] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:45:57] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.6s finished
# [I 2022-01-23 18:45:57,315] Trial 94 finished with value: -711380.2502395676 and parameters: {'colsample_bytree': 0.610460658944866, 'learning_rate': 0.1946870701493911, 'max_depth': 5, 'min_child_weight': 4, 'n_estimators': 286, 'reg_lambda': 3.955395790098293e-07, 'reg_alpha': 5.355795544148412e-06, 'sub_sample': 0.8571425264379499}. Best is trial 91 with value: -708176.1656207722.
# [18:45:57] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:45:57] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [18:45:57] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:45:57] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:45:57] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:45:57] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.6s finished
# [I 2022-01-23 18:45:58,068] Trial 95 finished with value: -712934.5270230606 and parameters: {'colsample_bytree': 0.5415830581488106, 'learning_rate': 0.10200022843956595, 'max_depth': 5, 'min_child_weight': 4, 'n_estimators': 300, 'reg_lambda': 8.676306927092159e-08, 'reg_alpha': 2.3626814771840424e-06, 'sub_sample': 0.8156439422801162}. Best is trial 91 with value: -708176.1656207722.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [18:45:58] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:45:58] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:45:58] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:45:58] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.6s finished
# [I 2022-01-23 18:45:58,817] Trial 96 finished with value: -709180.5828232719 and parameters: {'colsample_bytree': 0.5753051371767737, 'learning_rate': 0.15638446292791972, 'max_depth': 5, 'min_child_weight': 4, 'n_estimators': 283, 'reg_lambda': 4.75174666841083e-07, 'reg_alpha': 1.2121704007605986e-07, 'sub_sample': 0.842674132170863}. Best is trial 91 with value: -708176.1656207722.
# [18:45:58] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:45:58] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [18:45:58] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:45:59] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:45:59] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:45:59] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.6s finished
# [I 2022-01-23 18:45:59,574] Trial 97 finished with value: -709655.0390557679 and parameters: {'colsample_bytree': 0.5687299817412965, 'learning_rate': 0.15564516426004346, 'max_depth': 5, 'min_child_weight': 4, 'n_estimators': 284, 'reg_lambda': 6.054923189995665e-07, 'reg_alpha': 9.501133167796241e-07, 'sub_sample': 0.7486713786452432}. Best is trial 91 with value: -708176.1656207722.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [18:45:59] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:45:59] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:45:59] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.3s finished
# [I 2022-01-23 18:45:59,986] Trial 98 finished with value: -753702.033404493 and parameters: {'colsample_bytree': 0.6921348975687344, 'learning_rate': 0.150092382603583, 'max_depth': 2, 'min_child_weight': 4, 'n_estimators': 293, 'reg_lambda': 5.292636145221671e-07, 'reg_alpha': 1.190091079185507e-07, 'sub_sample': 0.7552722401047646}. Best is trial 91 with value: -708176.1656207722.
# [18:45:59] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:45:59] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:46:00] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [18:46:00] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:46:00] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:46:00] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:46:00] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.6s finished
# [I 2022-01-23 18:46:00,698] Trial 99 finished with value: -710605.3483168307 and parameters: {'colsample_bytree': 0.5007892856939719, 'learning_rate': 0.20296857138021185, 'max_depth': 5, 'min_child_weight': 4, 'n_estimators': 278, 'reg_lambda': 1.5162846602916995e-08, 'reg_alpha': 4.547010187248247e-07, 'sub_sample': 0.9122505892131235}. Best is trial 91 with value: -708176.1656207722.

# %%
study.best_params
# Out:
# {'colsample_bytree': 0.6081482318102632,
#  'learning_rate': 0.14995701851734167,
#  'max_depth': 5,
#  'min_child_weight': 4,
#  'n_estimators': 291,
#  'reg_lambda': 3.9652704245263507e-07,
#  'reg_alpha': 1.2822823054491217e-06,
#  'sub_sample': 0.8509083106841969}

# %%
XGB10 = XGBRegressor(colsample_bytree= 0.6081482318102632, learning_rate= 0.14995701851734167, max_depth= 5, min_child_weight= 4, n_estimators= 291,
reg_alpha= 1.2822823054491217e-06, reg_lambda=  3.9652704245263507e-07, sub_sample= 0.8509083106841969)
XGB10.fit(Z10_train, y10_train)
# Out:
# [18:46:00] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.6081482318102632,
#              enable_categorical=False, gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.14995701851734167,
#              max_delta_step=0, max_depth=5, min_child_weight=4, missing=nan,
#              monotone_constraints='()', n_estimators=291, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=0,
#              reg_alpha=1.2822823054491217e-06,
#              reg_lambda=3.9652704245263507e-07, scale_pos_weight=1,
#              sub_sample=0.8509083106841969, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
XGB10 = XGBRegressor(**study.best_params)
XGB10.fit(Z10_train, y10_train)
# Out:
# [18:46:01] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.6081482318102632,
#              enable_categorical=False, gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.14995701851734167,
#              max_delta_step=0, max_depth=5, min_child_weight=4, missing=nan,
#              monotone_constraints='()', n_estimators=291, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=0,
#              reg_alpha=1.2822823054491217e-06,
#              reg_lambda=3.9652704245263507e-07, scale_pos_weight=1,
#              sub_sample=0.8509083106841969, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
print_result(model=XGB10,
            X_train = Z10_train,
             X_test = Z10_test,
             y_train = y10_train,
             y_test = y10_test,
            title='Comparison of Model Train Test & Average Score')
# Out:
# Comparison of Model Train Test & Average Score
#
# Average Score RMSE is 2355449
#
# Train Score
# MSE IS 323663388536
# RSME IS 568914
#
# Test
# MSE IS 544562447659
# RSME IS 737944
#
# Train Test % Difference
# 22.91%

# %% [markdown]
# ## There is overfitting of the XGBoost model with 10% data removed

# %% [markdown]
#  ## Random Forest Regressor for 10% data removed

# %%
# Gridseach done multiple times to narrow in the best params
rf_params = {
    'n_estimators': [290, 300, 320, 350],
    'max_depth': [7, 9, 10, 12],
}
rf10 = GridSearchCV(rf, param_grid=rf_params, cv=5, n_jobs=-1)
rf10.fit(Z10_train, y10_train)
rf10.best_params_
# Out:
# {'max_depth': 9, 'n_estimators': 300}

# %%
print_result(model=rf10,
            X_train = Z10_train,
             X_test = Z10_test,
             y_train = y10_train,
             y_test = y10_test,
            title='Comparison of Model Train Test & Average Score')
# Out:
# Comparison of Model Train Test & Average Score
#
# Average Score RMSE is 2355449
#
# Train Score
# MSE IS 361675762476
# RSME IS 601394
#
# Test
# MSE IS 580685568332
# RSME IS 762027
#
# Train Test % Difference
# 21.08%

# %% [markdown]
# ## Overview for 10% data removed

# %% [markdown]
# ### Like wise to 5% data removed, the removal of 10% data is not entirely helpful as the overfit increase despite trying out different models. A table below will show the results of the 5% and 10% data removed.

# %% [markdown]
# | Data Type | RMSE (%) |
# | --- | --- |
# | Linear Regression with 5% removed| 6.21% |
# | Lasso Regression with 5% removed| 5.89% |
# | XGBoost with 5% removed| 20.11% |
# | Random Forest Regressor 5% removed| 25.39%|
# | Linear Regression with 10% removed| 7.39% |
# | Lasso Regression with 10% removed| 22.91% |
# | Random Forest Regressor 10% removed| 21.08%|

# %% [markdown]
# ## Splitting of dataset

# %% [markdown]
# ### From the observations in the "Cleaning of Dataset for houses" notebook, there is a huge difference between the tenure. There are 2 category of tenures, one belonging to the freehold which will exceed 99 years and another one is a lease of 99 years from the year it was bought.
#
# ### The difference in the tenure can drive up/down of the price of the property. Therefore, splitting of the dataset for tenure is required to carry out a more accurate modelling.

# %% [markdown]
# ## Dataset with houses tenure <=99years

# %% [markdown]
# ### Moving house tenure with <=99 years out from the main dataset, naming it as merged_house99

# %% [markdown]
# Calculation was done for linear regression, XGBoost and Random Forest
#
# | Data Type | RMSE (%) |
# | --- | --- |
# | Linear Regression with houses tenure <=99years| 100% |
# | XGBoost with 5% removed with houses tenure <=99years| 15.7% |
# | Random Foresr with 5% removed with houses tenure <=99years| 30.17% |

# %% [markdown]
# This linear regression is not accurate and the errors are too abnormal, this maybe due to the small dataset which does not capture the true relationship with the prices. This is because tenure with 99 years leases also fall unders the HDB pricing market as well. However, our property in this dataset belongs to private estate. Hence, to get an more accurate detail on the prices, we might need to add on this data to the HDB dataset as well.

# %%
merged_house99 = merged_house_10[merged_house_10['tenure'] <=99]

# %%
merged_house99.shape
# Out:
# (1119, 45)

# %%
merged_house99.head()
# Out:
#     index                project name      street name  tenure  no. of units  \
# 0       0  LANDED HOUSING DEVELOPMENT     PEARL ISLAND      86           1.0
# 3       3             PARADISE ISLAND  PARADISE ISLAND      83           1.0
# 21     21                CORAL ISLAND     CORAL ISLAND      83           1.0
# 55     55             PARADISE ISLAND  PARADISE ISLAND      83           1.0
# 88     88                SENTOSA COVE     CORAL ISLAND      83           1.0
#
#          price nett price  areasq type of area floor level  unit price psf  \
# 0   11288000.0          -  7011.0         Land           -          1610.0
# 3   11200000.0          -  8633.0         Land           -          1297.0
# 21  11000000.0          -  9325.0         Land           -          1180.0
# 55  10550000.0          -  8170.0         Land           -          1291.0
# 88  10300000.0          -  7511.0         Land           -          1371.0
#
#    date of sale  market segment_CCR  market segment_OCR  market segment_RCR  \
# 0      Jul-2017                   1                   0                   0
# 3      Apr-2018                   1                   0                   0
# 21     Mar-2017                   1                   0                   0
# 55     Aug-2020                   1                   0                   0
# 88     May-2021                   1                   0                   0
#
#     postal district_2.0  postal district_3.0  postal district_4.0  \
# 0                     0                    0                    1
# 3                     0                    0                    1
# 21                    0                    0                    1
# 55                    0                    0                    1
# 88                    0                    0                    1
#
#     postal district_5.0  postal district_8.0  postal district_9.0  \
# 0                     0                    0                    0
# 3                     0                    0                    0
# 21                    0                    0                    0
# 55                    0                    0                    0
# 88                    0                    0                    0
#
#     postal district_10.0  postal district_11.0  postal district_12.0  \
# 0                      0                     0                     0
# 3                      0                     0                     0
# 21                     0                     0                     0
# 55                     0                     0                     0
# 88                     0                     0                     0
#
#     postal district_13.0  postal district_14.0  postal district_15.0  \
# 0                      0                     0                     0
# 3                      0                     0                     0
# 21                     0                     0                     0
# 55                     0                     0                     0
# 88                     0                     0                     0
#
#     postal district_16.0  postal district_17.0  postal district_18.0  \
# 0                      0                     0                     0
# 3                      0                     0                     0
# 21                     0                     0                     0
# 55                     0                     0                     0
# 88                     0                     0                     0
#
#     postal district_19.0  postal district_20.0  postal district_21.0  \
# 0                      0                     0                     0
# 3                      0                     0                     0
# 21                     0                     0                     0
# 55                     0                     0                     0
# 88                     0                     0                     0
#
#     postal district_22.0  postal district_23.0  postal district_25.0  \
# 0                      0                     0                     0
# 3                      0                     0                     0
# 21                     0                     0                     0
# 55                     0                     0                     0
# 88                     0                     0                     0
#
#     postal district_26.0  postal district_27.0  postal district_28.0  \
# 0                      0                     0                     0
# 3                      0                     0                     0
# 21                     0                     0                     0
# 55                     0                     0                     0
# 88                     0                     0                     0
#
#     type_Detached  type_Semi-detached  type_Terrace  type of sale_New Sale  \
# 0               1                   0             0                      0
# 3               1                   0             0                      0
# 21              1                   0             0                      0
# 55              1                   0             0                      0
# 88              1                   0             0                      0
#
#     type of sale_Resale  type of sale_Sub Sale
# 0                     1                      0
# 3                     1                      0
# 21                    1                      0
# 55                    1                      0
# 88                    1                      0

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(y = merged_house99['price'], x = merged_house99['tenure'])
#Generally, there is a slight corelation that the prices increases as the tenure is higher
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='price'>

# %% [markdown]
# ### Moving house tenure with >99 years out from the main dataset, naming it as freehold

# %%
freehold = merged_house_10[merged_house_10['tenure'] >99]

# %%
freehold.shape
# Out:
# (7634, 45)

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(y = freehold['price'], x = freehold['tenure'])
# not much co relation as it is classfied as freehold, technically the freehold is under sales part is classified under freehold as long as it exceeds the normal 99 years
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='price'>

# %% [markdown]
# # Modelling for housing equal or lesser than 99 Tenure

# %%
X99 = merged_house99.drop(columns =['price', 'unit price psf', 'index', 'project name', 'street name', 'nett price', 'type of area','floor level','date of sale',])
y99 = merged_house99['price']

# %%
X99_train, X99_test, y99_train, y99_test = train_test_split(X99, y99, test_size =0.25, random_state=42)

# %%
Z99_train = sc.fit_transform(X99_train)
Z99_test = sc.transform(X99_test)

# %%
lr99 =LinearRegression()

# %%
lr99.fit(Z99_train, y99_train);

# %%
print_result(model= lr99,
            X_train = Z99_train,
             X_test = Z99_test,
             y_train = y99_train,
             y_test = y99_test,
            title='Comparison of Model Train Test & Average Score')
# Out:
# Comparison of Model Train Test & Average Score
#
# Average Score RMSE is 2355449
#
# Train Score
# MSE IS 139514729722
# RSME IS 373516
#
# Test
# MSE IS 31088788561560048512282832744218624
# RSME IS 176320130902741920
#
# Train Test % Difference
# 100.0%

# %%
y_pred_test_99 = lr99.predict(Z99_test)

# Visualizing actual prices vs predicted values
plt.scatter(y99_test, y_pred_test_99)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual Cost Price vs Predicted Cost Price")
plt.show()

# %%
y_pred_train99 = lr99.predict(Z99_train)
print(metrics.mean_squared_error(y99_train, y_pred_train99))
print(np.sqrt(metrics.mean_squared_error(y99_train, y_pred_train99)))
# Out:
# 139514729722.2219
# 373516.7060818323

# %%
y_pred_test99 = lr99.predict(Z99_test)
print(metrics.mean_squared_error(y99_test, y_pred_test99))
print(np.sqrt(metrics.mean_squared_error(y99_test, y_pred_test99)))
# this value is too huge
# Out:
# 3.108878856156005e+34
# 1.7632013090274192e+17

# %% [markdown]
# ### Carrying out XGboost Modelling for merged_house99

# %%
def xgb(search):
    colsample_bytree = search.suggest_float("colsample_bytree", 0.1, 1.0)
    learning_rate = search.suggest_float("learning_rate", 0.1, 1.0) 
    max_depth = search.suggest_int("max_depth",1, 5)
    min_child_weight = search.suggest_int("min_child_weight", 1, 5)
    n_estimator = search.suggest_int("n_estimators", 100, 300)
    reg_lambda = search.suggest_loguniform("reg_lambda", 1e-8, 100)
    reg_alpha = search.suggest_loguniform("reg_alpha", 1e-8, 100)
    sub_sample = search.suggest_float("sub_sample", 0.1, 1.0)
    
    model = XGBRegressor(random_state = 42,
                         colsample_bytree = colsample_bytree,
                         learning_rate = learning_rate,
                         max_depth = max_depth,
                         min_child_weight = min_child_weight,
                         n_estimator = n_estimator,
                         reg_lambda = reg_lambda, 
                         reg_alpha = reg_alpha,
                         sub_sample = sub_sample,
                         n_jobs = -1
                        )
    
    score = cross_val_score(model, Z99_train, y99_train, scoring = 'neg_root_mean_squared_error', cv = 5, verbose = 1)
    mean_score = score.mean()
    std_score = score.std()
    
    accuracy = mean_score - std_score
    
    return accuracy

study = optuna.create_study(direction = 'maximize', sampler = TPESampler(seed =42))
study.optimize(xgb, n_trials=100)
# Out:
# [I 2022-01-23 18:46:42,497] A new study created in memory with name: no-name-aa05cd28-af51-452c-b099-2214d09b5e8d
# [18:46:42] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:46:42] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:46:42] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:46:42] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.2s finished
# [I 2022-01-23 18:46:42,763] Trial 0 finished with value: -590541.836853709 and parameters: {'colsample_bytree': 0.4370861069626263, 'learning_rate': 0.9556428757689246, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators':
 'max_depth': 2, 'min_child_weight': 4, 'n_estimators': 255, 'reg_lambda': 1.1177851982557315e-06, 'reg_alpha': 1.2061093148943314e-07, 'sub_sample': 0.6373742586007972}. Best is trial 77 with value: -374782.0443093943.
# [18:47:04] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:47:04] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:47:04] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:47:04] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:47:05] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.1s finished
# [I 2022-01-23 18:47:05,295] Trial 97 finished with value: -465885.5250755844 and parameters: {'colsample_bytree': 0.9607795096729332, 'learning_rate': 0.19260783964355332, 'max_depth': 1, 'min_child_weight': 4, 'n_estimators': 235, 'reg_lambda': 3.144886733006685e-07, 'reg_alpha': 1.0002608605184503e-08, 'sub_sample': 0.6578950059963944}. Best is trial 77 with value: -374782.0443093943.
# [18:47:05] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:47:05] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:47:05] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:47:05] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:47:05] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.1s finished
# [I 2022-01-23 18:47:05,531] Trial 98 finished with value: -408931.9556023343 and parameters: {'colsample_bytree': 0.8400108989716151, 'learning_rate': 0.20627551255898102, 'max_depth': 2, 'min_child_weight': 3, 'n_estimators': 244, 'reg_lambda': 5.52488673634511e-08, 'reg_alpha': 2.3356787301191638e-07, 'sub_sample': 0.6015430678596696}. Best is trial 77 with value: -374782.0443093943.
# [18:47:05] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:47:05] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:47:05] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:47:05] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:47:05] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.1s finished
# [I 2022-01-23 18:47:05,732] Trial 99 finished with value: -474866.36739757354 and parameters: {'colsample_bytree': 0.12621244041302543, 'learning_rate': 0.1503203270086214, 'max_depth': 2, 'min_child_weight': 4, 'n_estimators': 232, 'reg_lambda': 1.3059892006465084e-07, 'reg_alpha': 9.567454299320424e-08, 'sub_sample': 0.554462174468599}. Best is trial 77 with value: -374782.0443093943.
# [18:47:05] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:47:05] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:47:05] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:47:05] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:47:05] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.

# %%
study.best_params
# Out:
# {'colsample_bytree': 0.7783854310513393,
#  'learning_rate': 0.10136903379517707,
#  'max_depth': 2,
#  'min_child_weight': 4,
#  'n_estimators': 225,
#  'reg_lambda': 8.142000463106808e-08,
#  'reg_alpha': 9.339643332907624e-07,
#  'sub_sample': 0.6570799049708295}

# %%
XGB99 = XGBRegressor(**study.best_params)
XGB99.fit(Z99_train, y99_train)
# Out:
# [18:47:05] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.7783854310513393,
#              enable_categorical=False, gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.10136903379517707,
#              max_delta_step=0, max_depth=2, min_child_weight=4, missing=nan,
#              monotone_constraints='()', n_estimators=225, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=0,
#              reg_alpha=9.339643332907624e-07, reg_lambda=8.142000463106808e-08,
#              scale_pos_weight=1, sub_sample=0.6570799049708295, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
print_result(model=XGB99,
            X_train = Z99_train,
             X_test = Z99_test,
             y_train = y99_train,
             y_test = y99_test,
            title='Comparison of Model Train Test & Average Score')
# Out:
# Comparison of Model Train Test & Average Score
#
# Average Score RMSE is 2355449
#
# Train Score
# MSE IS 60667498622
# RSME IS 246307
#
# Test
# MSE IS 85371547246
# RSME IS 292184
#
# Train Test % Difference
# 15.7%

# %% [markdown]
# ### XGBoost is overfitted for 99 years lease

# %% [markdown]
# ### Carrying out RFRegressor for merged_house99

# %%
# Gridseach done multiple times to narrow in the best params
rf_params = {
    'n_estimators': [40, 41, 42, 43, 44, 45, 46],
    'max_depth': [7, 8, 9],
}
rf99 = GridSearchCV(rf, param_grid=rf_params, cv=5, n_jobs=-1)
rf99.fit(Z99_train, y99_train)
rf99.best_params_
# Out:
# {'max_depth': 8, 'n_estimators': 45}

# %%
print_result(model=rf99,
            X_train = Z99_train,
             X_test = Z99_test,
             y_train = y99_train,
             y_test = y99_test,
            title='Comparison of Model Train Test & Average Score')
# Out:
# Comparison of Model Train Test & Average Score
#
# Average Score RMSE is 2355449
#
# Train Score
# MSE IS 42259279825
# RSME IS 205570
#
# Test
# MSE IS 86661875685
# RSME IS 294383
#
# Train Test % Difference
# 30.17%

# %% [markdown]
# ## Dataset with houses tenure categorized as freehold

# %%
freehold = merged_house_10[merged_house_10['tenure'] >99]

# %%
freehold.shape
# Out:
# (7634, 45)

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(y = freehold['price'], x = freehold['tenure'])
# to see is there any co relation in price and tenure
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='price'>

# %%
XFH = freehold.drop(columns =['price', 'unit price psf', 'index', 'project name', 'street name', 'nett price', 'type of area','floor level','date of sale',])
yFH = freehold['price']

# %%
XFH_train, XFH_test, yFH_train, yFH_test = train_test_split(XFH, yFH, test_size =0.25, random_state=42)

# %%
lrFH= LinearRegression()

# %%
ZFH_train = sc.fit_transform(XFH_train)
ZFH_test = sc.transform(XFH_test)
lrFH.fit(ZFH_train, yFH_train);

# %%
print_result(model= lrFH,
            X_train = ZFH_train,
             X_test = ZFH_test,
             y_train = yFH_train,
             y_test = yFH_test,
            title='Comparison of Model Train Test & Average Score')
# Out:
# Comparison of Model Train Test & Average Score
#
# Average Score RMSE is 2355449
#
# Train Score
# MSE IS 625210253388
# RSME IS 790702
#
# Test
# MSE IS 646643528876
# RSME IS 804141
#
# Train Test % Difference
# 1.67%

# %%
y_pred_testFH = lrFH.predict(ZFH_test)

# Visualizing actual prices vs predicted values
plt.scatter(yFH_test, y_pred_testFH)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual Cost Price vs Predicted Cost Price")
plt.show()

# %% [markdown]
# ### There is no overfitting for this model. This could be due to the larger data set, it is notice that only the more expensive properties are predicted wrongly.

# %% [markdown]
# ### A check on XGboost for Freehold

# %%
def xgb(search):
    colsample_bytree = search.suggest_float("colsample_bytree", 0.1, 1.0)
    learning_rate = search.suggest_float("learning_rate", 0.1, 1.0) 
    max_depth = search.suggest_int("max_depth",1, 5)
    min_child_weight = search.suggest_int("min_child_weight", 1, 5)
    n_estimator = search.suggest_int("n_estimators", 100, 300)
    reg_lambda = search.suggest_loguniform("reg_lambda", 1e-8, 100)
    reg_alpha = search.suggest_loguniform("reg_alpha", 1e-8, 100)
    sub_sample = search.suggest_float("sub_sample", 0.1, 1.0)
    
    model = XGBRegressor(random_state = 42,
                         colsample_bytree = colsample_bytree,
                         learning_rate = learning_rate,
                         max_depth = max_depth,
                         min_child_weight = min_child_weight,
                         n_estimator = n_estimator,
                         reg_lambda = reg_lambda, 
                         reg_alpha = reg_alpha,
                         sub_sample = sub_sample,
                         n_jobs = -1
                        )
    
    score = cross_val_score(model, ZFH_train, yFH_train, scoring = 'neg_root_mean_squared_error', cv = 5, verbose = 1)
    mean_score = score.mean()
    std_score = score.std()
    
    accuracy = mean_score - std_score
    
    return accuracy

study = optuna.create_study(direction = 'maximize', sampler = TPESampler(seed =42))
study.optimize(xgb, n_trials=100)
# Out:
# [I 2022-01-23 18:47:08,040] A new study created in memory with name: no-name-29571215-2b51-442a-9104-c3971d72f523
# [18:47:08] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [18:47:08] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:47:08] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:47:08] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:47:08] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.4s finished
# [I 2022-01-23 18:47:08,577] Trial 0 finished with value: -823575.8546349031 and parameters: {'colsample_bytree': 0.4370861069626263, 'learning_rate': 0.9556428757689246, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 131, 'reg_lambda': 3.6303224667798554e-07, 'reg_alpha': 3.809220577048033e-08, 'sub_sample': 0.8795585311974417}. Best is trial 0 with value: -823575.8546349031.
# [18:47:08] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:47:08] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [18:47:08] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:47:08] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.2s finished
# [I 2022-01-23 18:47:08,891] Trial 1 finished with value: -822506.0122252147 and parameters: {'colsample_bytree': 0.6410035105688879, 'learning_rate': 0.737265320016441, 'max_depth': 1, 'min_child_weight': 5, 'n_estimators': 267, 'reg_lambda': 1.3285903900544182e-06, 'reg_alpha': 6.580360277501306e-07, 'sub_sample': 0.2650640588680905}. Best is trial 1 with value: -822506.0122252147.
# [18:47:08] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:47:08] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:47:08] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [18:47:09] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:47:09] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:47:09] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.4s finished
# [I 2022-01-23 18:47:09,345] Trial 2 finished with value: -789247.9805683 and parameters: {'colsample_bytree': 0.373818018663584, 'learning_rate': 0.5722807884690141, 'max_depth': 3, 'min_child_weight': 2, 'n_estimators':
 'max_depth': 5, 'min_child_weight': 3, 'n_estimators': 207, 'reg_lambda': 0.004880134787889033, 'reg_alpha': 1.9607720235176794e-05, 'sub_sample': 0.5508939665995031}. Best is trial 96 with value: -748159.6946895644.
# [18:48:16] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [18:48:16] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:48:16] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:48:16] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:48:16] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.7s finished
# [I 2022-01-23 18:48:16,964] Trial 97 finished with value: -755097.1538678408 and parameters: {'colsample_bytree': 0.7150594443007792, 'learning_rate': 0.1461001916826848, 'max_depth': 5, 'min_child_weight': 3, 'n_estimators': 200, 'reg_lambda': 0.004025788716853396, 'reg_alpha': 1.252212092843719e-05, 'sub_sample': 0.5429257574128954}. Best is trial 96 with value: -748159.6946895644.
# [18:48:16] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [18:48:17] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:48:17] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:48:17] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:48:17] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.7s finished
# [I 2022-01-23 18:48:17,822] Trial 98 finished with value: -752509.3568447601 and parameters: {'colsample_bytree': 0.6791604591344911, 'learning_rate': 0.2004256798870958, 'max_depth': 5, 'min_child_weight': 3, 'n_estimators': 183, 'reg_lambda': 0.0037895757426385413, 'reg_alpha': 4.063202907821402e-06, 'sub_sample': 0.5188796392974739}. Best is trial 96 with value: -748159.6946895644.
# [18:48:17] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [18:48:17] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:48:18] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:48:18] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [18:48:18] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.6s finished
# [I 2022-01-23 18:48:18,594] Trial 99 finished with value: -757629.90133481 and parameters: {'colsample_bytree': 0.6776957725442448, 'learning_rate': 0.19445185027969686, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 181, 'reg_lambda': 0.002937972906810251, 'reg_alpha': 2.802954438699038e-06, 'sub_sample': 0.5834692093038071}. Best is trial 96 with value: -748159.6946895644.
# [18:48:18] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "n_estimator", "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.

# %%
study.best_params
# Out:
# {'colsample_bytree': 0.7201850925222163,
#  'learning_rate': 0.17608220702170052,
#  'max_depth': 5,
#  'min_child_weight': 3,
#  'n_estimators': 207,
#  'reg_lambda': 0.004880134787889033,
#  'reg_alpha': 1.9607720235176794e-05,
#  'sub_sample': 0.5508939665995031}

# %%
XGBFH = XGBRegressor(**study.best_params)
XGBFH.fit(ZFH_train, yFH_train)
# Out:
# [18:48:18] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:576:
# Parameters: { "sub_sample" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.7201850925222163,
#              enable_categorical=False, gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.17608220702170052,
#              max_delta_step=0, max_depth=5, min_child_weight=3, missing=nan,
#              monotone_constraints='()', n_estimators=207, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=0,
#              reg_alpha=1.9607720235176794e-05, reg_lambda=0.004880134787889033,
#              scale_pos_weight=1, sub_sample=0.5508939665995031, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
print_result(model= XGBFH,
            X_train = ZFH_train,
             X_test = ZFH_test,
             y_train = yFH_train,
             y_test = yFH_test,
            title='Comparison of Model Train Test & Average Score')
# Out:
# Comparison of Model Train Test & Average Score
#
# Average Score RMSE is 2355449
#
# Train Score
# MSE IS 337746003318
# RSME IS 581159
#
# Test
# MSE IS 573408436356
# RSME IS 757237
#
# Train Test % Difference
# 23.25%

# %% [markdown]
# # Conclusion
#
# It was noticed that most of the tree algorithms is not suitable for this dataset. However, our linear regression model was able to capture a none overfitted model for houses which is categorized as freehold with 1.67% RMSE.'
#
# The RMSE is chosen as our main metrics because it punishes predicted value that has a greater difference the the actual value. This is imporant for us as we do not want to undervalue or overvalue a property unit. The RMSE also gives us a better intution of the error which is the target varaible (price). This si will tell us how far off the predicted and the actual value are.
#
# For the 99 years lease category, we are unable to get an accurate view over it as the RMSE error is abnormal. This could be due to the small dataset extracted out from the actual data. Furthermore, the 99 years lease fall under the same category as HDB estate. Therefore, this could be a reason why the private residential area does not have a sufficient data for the 99 years. As such, the dataset cannot capture the true releationship from the actual and predicted prices.
